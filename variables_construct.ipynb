# %% [markdown]
# #### This code is used to construct variables used in baseline regression
# - open B-A (x): dummy difference (the state is open to interstate banking in the year) between target B and acquirer A
# - Acq. vol. A buys B (y1): total transaction value of acquisitions made by firms located in A targeting firms in B/total transaction value of acquisition made by firms located in A
# - Acq. vol. A buys B (y2): the number of transactions made by firms located in A targeting firms in B/the number of transactions made by firms located in A
# - Within-state acquisition growth
# - Tobin’s q B-A
# - Stock return B-A
# - GDP growth B-A
# - GDP per capita B-A
# - Unemployment B-A
# - Corporate tax B-A
# - Anti-combination B-A
# - Industry dissimilarity A&B
# - Economic correlation A&B

# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',1000)

# %%
## Filter samples
ma_path = '../M&A1980_1997/'
ma_df = pd.DataFrame()
for f in os.listdir(ma_path):
    df = pd.read_excel(os.path.join(ma_path,f),header = 1)
    df = df.iloc[:-10,:]
    ma_df = pd.concat([ma_df,df])

### exclude finance and utility industry and other exceptions
ma_df = ma_df[~ma_df['Target\nPrimary\n  SIC\n Code'].isin(range(6000,7000))]
ma_df = ma_df[~ma_df['Target\nPrimary\n  SIC\n Code'].isin(range(4900,5000))]
ma_df = ma_df[~ma_df['Acquiror\nPrimary\n  SIC\n  Code'].isin(range(6000,7000))]
ma_df = ma_df[~ma_df['Acquiror\nPrimary\n  SIC\n  Code'].isin(range(4900,5000))]

ma_df = ma_df[~ma_df['Target\nPrimary\n  SIC\n Code'].isin(['619A','999F','499A','999G','619B','999A','999B','999C','999D','999E'])]
ma_df = ma_df[~ma_df['Acquiror\nPrimary\n  SIC\n  Code'].isin(['619A','999F','499A','999G','619B','999A','999B','999C','999D','999E'])]

ma_df['Target\nPrimary\n  SIC\n Code'] = ma_df['Target\nPrimary\n  SIC\n Code'].astype(int)
ma_df['Acquiror\nPrimary\n  SIC\n  Code'] = ma_df['Acquiror\nPrimary\n  SIC\n  Code'].astype(int)
print('There are only ',len(ma_df),' left.')
## exclude state as 'Unknown','Foreign'
ma_df = ma_df[(~ma_df['Acquiror State'].isin(['Unknown','Foreign','Virgin Islands','Cayman Islands']))&(~ma_df['Target State'].isin(['Unknown','Foreign','Virgin Islands','Cayman Islands']))]
ma_df.dropna(subset=['Target State','Acquiror State'],how='any',inplace=True)
print('There are only ',len(ma_df),' left.')

ma_df['announce_year'] = ma_df['  Date\nAnnounced'].apply(lambda x:x.year)

## State and state abbr
state_abbreviations = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "D. of Columbia":"DC",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY"
}

state_full = {}
for k,v in state_abbreviations.items():
    state_full[v] = k
# Out:
# There are only  64377  left.
# There are only  53403  left.

# %%
## before construct measures, we firstly replicate Table 1
ma_df['same_state'] = ma_df.apply(lambda row: 1 if row['Acquiror State']==row['Target State'] else 0, axis=1)
acquire_grouped = ma_df.groupby(by = ['Acquiror State','same_state'])
acquire_count = acquire_grouped['Target Name'].count()
acquire_count = acquire_count.unstack(level=-1)
acquire_count.columns = ['NC','NI']

acquire_volume = acquire_grouped['Value of\nTransaction\n($mil)'].sum(numeric_only = True)
acquire_volume = acquire_volume.unstack(level=-1)
acquire_volume.columns = ['VC','VI']

target_grouped = ma_df.groupby(by = ['Target State','same_state'])
target_count =target_grouped['Acquiror Name'].count()
target_count = target_count.unstack(level=-1)
target_count.columns = ['NC','NI']

target_volume = target_grouped['Value of\nTransaction\n($mil)'].sum(numeric_only = True)
target_volume = target_volume.unstack(level=-1)
target_volume.columns = ['VC','VI']


table1 = pd.merge(acquire_count,target_count,left_index=True,right_index=True,suffixes=('_acquire','_target'))
table1['N_acquire'] = table1['NI_acquire']+table1['NC_acquire']
table1['N_target'] = table1['NI_target']+table1['NC_target']
table1['%NC_acquire'] = table1['NC_acquire']/table1['NI_acquire'] 
table1['%NC_target'] = table1['NC_target']/table1['NI_target']


table11 = pd.merge(acquire_volume,target_volume,left_index=True,right_index=True,suffixes=('_acquire','_target'))
table1 =pd.merge(table1,table11,left_index=True,right_index=True)
table1.drop(columns=['NI_acquire','NI_target','VI_acquire','VI_target'],inplace=True)
table1.to_csv('./table_out/Table1.csv')

# %% [markdown]
# ##### Construct x - open B-A

# %%
policy = pd.read_excel('../data/policy.xlsx')
open_policy = policy.iloc[:,2:]
open_policy['state'] = open_policy['State.1'].apply(lambda x:state_full[x])
years = range(1980,1998)
years = np.tile(years, len(open_policy))

states = open_policy['state'].values
shuffle_states = np.tile(states,len(states))
shuffle_years = np.tile(years,len(states))
states = states.repeat(18)

open_df = pd.DataFrame([states,years]).T
open_df.columns = ['state','year']
open_df = pd.merge(open_df,open_policy,left_on = 'state',right_on='state')
open_df['open'] = open_df.apply(lambda x: 1 if x['year']>=x['Interstate banking'] else 0,axis =1)

open_diff = pd.merge(open_df,open_df,how = 'outer',left_on = 'year',right_on = 'year',suffixes=('_target','_acquire'))
open_diff = open_diff[open_diff['state_target']!=open_diff['state_acquire']]
open_diff['open_B-A'] = open_diff['open_target']-open_diff['open_acquire']
open_diff.rename(columns={'state_target':'Target State','state_acquire':'Acquiror State','year':'announce_year'},inplace=True)
open_diff['announce_year'] = open_diff['announce_year'].astype(int)

# %% [markdown]
# ##### Construct y - acquire volume B-A

# %%
group_acq_tar_year =ma_df.groupby(by = ['Acquiror State','Target State','announce_year'])
group_acq_year = ma_df.groupby(by = ['Acquiror State','announce_year'])

count_df = group_acq_tar_year['Target Name'].count()
count_df = count_df.reset_index()
count_df = count_df[count_df['Target State']!=count_df['Acquiror State']]
count_all =  group_acq_year['Target Name'].count()
count_all = count_all.reset_index()
count_df = pd.merge(count_df,count_all,left_on=['Acquiror State','announce_year'],right_on=['Acquiror State','announce_year'],suffixes=('_acquire','_all'))
count_df['Acq_Count_A-B'] = count_df['Target Name_acquire']/count_df['Target Name_all']
count_df['announce_year'] = count_df['announce_year'].astype(int)

##NOTE: Can we assume those with no value as 0???
volume_df = group_acq_tar_year['Value of\nTransaction\n($mil)'].agg(lambda x: x.sum(skipna= False))#sum()
volume_df = volume_df.reset_index()
volume_df = volume_df[volume_df['Target State']!=volume_df['Acquiror State']]
volume_all =  group_acq_year['Value of\nTransaction\n($mil)'].agg(lambda x: x.sum(skipna= False))# sum()
volume_all = volume_all.reset_index()
volume_df['announce_year'] = volume_df['announce_year'].astype(int)
volume_df = pd.merge(volume_df,volume_all,left_on=['Acquiror State','announce_year'],right_on=['Acquiror State','announce_year'],suffixes=('_acquire','_all'))
volume_df['Acq_Vol_A-B'] = volume_df['Value of\nTransaction\n($mil)_acquire']/volume_df['Value of\nTransaction\n($mil)_all']
volume_df.loc[volume_df['Acq_Vol_A-B'].isna(),'Acq_Vol_A-B'] = 'unknown'

acq_df = pd.merge(count_df,volume_df,on = ['Acquiror State','Target State','announce_year'])
acq_df['announce_year'] = acq_df['announce_year'].astype(int)

reg_df = pd.merge(acq_df,open_diff,how = 'right',on = ['Acquiror State','Target State','announce_year'])
reg_df.loc[reg_df['Acq_Count_A-B'].isna(),'Acq_Count_A-B'] = 0
reg_df.loc[reg_df['Acq_Vol_A-B'].isna(),'Acq_Vol_A-B'] = 0
reg_df.loc[reg_df['Acq_Vol_A-B']=='unknown','Acq_Vol_A-B'] = None

# %% [markdown]
# ##### Construct controls

# %%
## within state 
volume_all = pd.merge(open_df[['state', 'year']],volume_all,how='left',left_on=['state', 'year'],right_on=['Acquiror State','announce_year'])
volume_all['Value of\nTransaction\n($mil)'] = volume_all['Value of\nTransaction\n($mil)'].fillna(0)

volume_all.sort_values(by=['state','year'],ascending=[True,True],inplace=True)
volume_all['shift_Value of\nTransaction\n($mil)'] = volume_all.groupby(by = ['state'])['Value of\nTransaction\n($mil)'].shift()
def get_growth(x):
    if x['shift_Value of\nTransaction\n($mil)']!=0:
        return (x['Value of\nTransaction\n($mil)']-x['shift_Value of\nTransaction\n($mil)'])/x['shift_Value of\nTransaction\n($mil)'] 
    elif x['Value of\nTransaction\n($mil)']==0:
        return 0
    else:
        return 1

volume_all['growth'] = volume_all.apply(lambda x:get_growth(x),axis=1)
reg_df = pd.merge(reg_df,volume_all[['state', 'year','growth']],left_on=['Acquiror State','announce_year'],right_on=['state','year'])
reg_df = pd.merge(reg_df,volume_all[['state', 'year','growth']],left_on=['Target State','announce_year'],right_on=['state','year'],suffixes=('_acquire','_target'))
##

# %%
## GDP growth and GDP percapita
gdp = pd.read_csv('../data/GDP-by-state-industry.csv')
gdp.drop(columns=['ID ','COMPONENT                                                    ','FIPS   '],inplace=True)
gdp = gdp.iloc[:-6]
gdp.columns = [c.strip() for c in gdp.columns]
##NOTE: There are some cases that it is labeled as (L), which means the value is below 0.5 million, we simply replace it with 0.5
##NOTE: we do not know whether or not it is real or nominal GDP
gdp = gdp.replace('   (L)  ','0.5')
gdp['REGION'] = gdp['REGION'].str.strip()
gdp.loc[gdp['REGION']=='Dist. of Col.','REGION'] = 'D. of Columbia'

gdp_state = gdp[gdp['CODE']==0]
gdp_state = gdp_state[:-9]
gdp_state.drop(columns=[ 'CODE','INDUSTRY'],inplace=True)
states = gdp_state['REGION'].values
states = states.repeat(21)

t = gdp_state.iloc[:,1:].stack()
t = t.reset_index()
t.columns = ['index','year','GDP']
t['GDP'] = t['GDP'].astype(float)
t['state'] = states
t.drop(columns=['index'],inplace=True)
t['GDP_shift'] = t.groupby('state')['GDP'].shift()
t['GDP_growth'] = (t['GDP']-t['GDP_shift'])/t['GDP_shift']

t['year'] = t['year'].astype(int)


population = pd.read_excel('../data/popest-annual-historical.xls',sheet_name='States')
population.loc[population['Area Name']=='District of Columbia','Area Name'] = 'D. of Columbia'
population.columns =[str(c).strip() for c in population.columns]
population.rename(columns={'Area Name':'REGION'},inplace=True)

tt = population.iloc[:,1:].stack()
tt = tt.reset_index()
tt.columns = ['index','year','population']
tt['population'] = tt['population'].astype(int)
states_po= population['REGION'].values
states_po = states_po.repeat(41)
tt['state'] = states_po
tt.drop(columns=['index'],inplace=True)
tt['year'] = tt['year'].astype(int)

tem = pd.merge(t,tt,on = ['state','year'])
tem['GDP_per_capita'] = tem['GDP']/tem['population']

reg_df['announce_year'] = reg_df['announce_year'].astype(int)
tt = pd.merge(reg_df,tem,left_on=['Acquiror State','announce_year'],right_on=['state','year'])
reg_df = pd.merge(tt,tem,left_on=['Target State','announce_year'],right_on=['state','year'],suffixes=('_acquire','_target'))
reg_df.drop(columns=['state_acquire','GDP_shift_acquire','year_target','state_target','GDP_shift_target','year_acquire'],inplace=True)
reg_df['GDP_growth_B-A'] = reg_df['GDP_growth_target'] - reg_df['GDP_growth_acquire']
reg_df['GDP_per_capita_B-A'] = reg_df['GDP_per_capita_target'] - reg_df['GDP_per_capita_acquire']
reg_df
# Out:
# C:\Users\chuxu\AppData\Local\Temp\ipykernel_5136\2919322394.py:50: FutureWarning: Passing 'suffixes' which cause duplicate columns {'state_acquire', 'year_acquire'} in the result is deprecated and will raise a MergeError in a future version.
#   reg_df = pd.merge(tt,tem,left_on=['Target State','announce_year'],right_on=['state','year'],suffixes=('_acquire','_target'))
#       Acquiror State Target State  announce_year  Target Name_acquire  \
# 0            Alabama       Alaska           1980                  NaN
# 1           Arkansas       Alaska           1980                  NaN
# 2            Arizona       Alaska           1980                  NaN
# 3         California       Alaska           1980                  NaN
# 4           Colorado       Alaska           1980                  NaN
# ...              ...          ...            ...                  ...
# 45895     Washington      Alabama           1997                  NaN
# 45896      Wisconsin      Alabama           1997                  2.0
# 45897  West Virginia      Alabama           1997                  NaN
# 45898        Wyoming      Alabama           1997                  NaN
# 45899         Alaska      Alabama           1997                  NaN
#
#        Target Name_all  Acq_Count_A-B  Value of\nTransaction\n($mil)_acquire  \
# 0                  NaN       0.000000                                    NaN
# 1                  NaN       0.000000                                    NaN
# 2                  NaN       0.000000                                    NaN
# 3                  NaN       0.000000                                    NaN
# 4                  NaN       0.000000                                    NaN
# ...                ...            ...                                    ...
# 45895              NaN       0.000000                                    NaN
# 45896             95.0       0.021053                                   43.5
# 45897              NaN       0.000000                                    NaN
# 45898              NaN       0.000000                                    NaN
# 45899              NaN       0.000000                                    NaN
#
#        Value of\nTransaction\n($mil)_all Acq_Vol_A-B State.1_target  \
# 0                                    NaN           0             AK
# 1                                    NaN           0             AK
# 2                                    NaN           0             AK
# 3                                    NaN           0             AK
# 4                                    NaN           0             AK
# ...                                  ...         ...            ...
# 45895                                NaN           0             AL
# 45896                                NaN        None             AL
# 45897                                NaN           0             AL
# 45898                                NaN           0             AL
# 45899                                NaN           0             AL
#
#        Interstate banking_target Intrastate branching_target  open_target  \
# 0                           1982                 before 1970            0
# 1                           1982                 before 1970            0
# 2                           1982                 before 1970            0
# 3                           1982                 before 1970            0
# 4                           1982                 before 1970            0
# ...                          ...                         ...          ...
# 45895                       1987                        1981            1
# 45896                       1987                        1981            1
# 45897                       1987                        1981            1
# 45898                       1987                        1981            1
# 45899                       1987                        1981            1
#
#       State.1_acquire  Interstate banking_acquire  \
# 0                  AL                        1987
# 1                  AR                        1989
# 2                  AZ                        1986
# 3                  CA                        1987
# 4                  CO                        1988
# ...               ...                         ...
# 45895              WA                        1987
# 45896              WI                        1987
# 45897              WV                        1988
# 45898              WY                        1987
# 45899              AK                        1982
#
#       Intrastate branching_acquire  open_acquire  open_B-A  growth_acquire  \
# 0                             1981             0         0             NaN
# 1                             1994             0         0             NaN
# 2                      before 1970             0         0             NaN
# 3                      before 1970             0         0             NaN
# 4                             1991             0         0             NaN
# ...                            ...           ...       ...             ...
# 45895                         1985             1         0             0.0
# 45896                         1990             1         0             0.0
# 45897                         1987             1         0             0.0
# 45898                         1988             1         0             0.0
# 45899                  before 1970             1         0             0.0
#
#        growth_target  GDP_acquire  GDP_growth_acquire  population_acquire  \
# 0                NaN      36006.0            0.073684             3900368
# 1                NaN      20100.0            0.061134             2288738
# 2                NaN      30431.0            0.114444             2737774
# 3                NaN     324407.0            0.111394            23800800
# 4                NaN      38151.0            0.132212             2908803
# ...              ...          ...                 ...                 ...
# 45895            0.0     174412.0            0.078215             5674747
# 45896            0.0     148831.0            0.049917             5266213
# 45897            0.0      38517.0            0.031355             1819113
# 45898            0.0      16041.0            0.019641              489451
# 45899            0.0      26884.0            0.030710              612968
#
#        GDP_per_capita_acquire  GDP_target  GDP_growth_target  \
# 0                    0.009231     15138.0           0.393538
# 1                    0.008782     15138.0           0.393538
# 2                    0.011115     15138.0           0.393538
# 3                    0.013630     15138.0           0.393538
# 4                    0.013116     15138.0           0.393538
# ...                       ...         ...                ...
# 45895                0.030735    102533.0           0.046885
# 45896                0.028261    102533.0           0.046885
# 45897                0.021174    102533.0           0.046885
# 45898                0.032773    102533.0           0.046885
# 45899                0.043859    102533.0           0.046885
#
#        population_target  GDP_per_capita_target  GDP_growth_B-A  \
# 0                 405315               0.037349        0.319853
# 1                 405315               0.037349        0.332404
# 2                 405315               0.037349        0.279094
# 3                 405315               0.037349        0.282144
# 4                 405315               0.037349        0.261326
# ...                  ...                    ...             ...
# 45895            4367935               0.023474       -0.031329
# 45896            4367935               0.023474       -0.003032
# 45897            4367935               0.023474        0.015530
# 45898            4367935               0.023474        0.027244
# 45899            4367935               0.023474        0.016176
#
#        GDP_per_capita_B-A
# 0                0.028117
# 1                0.028567
# 2                0.026233
# 3                0.023719
# 4                0.024233
# ...                   ...
# 45895           -0.007261
# 45896           -0.004787
# 45897            0.002301
# 45898           -0.009299
# 45899           -0.020385
#
# [45900 rows x 30 columns]

# %%
# Industry dissimilarity A&B
gdp = gdp[~gdp['CODE'].isin([0,5000,10000,30000,40000,50000,60000,70000,80000,90000,100000,110000])]
industry_df = pd.DataFrame()
states = gdp.REGION.unique()
for r in states:
    for r1 in states:
        if r==r1:
            continue
        curr_r = gdp[gdp['REGION']==r]
        curr_r1 = gdp[gdp['REGION']==r1]

        curr_r_ind = curr_r['CODE']
        curr_r_ind = np.tile(curr_r_ind,21)
        curr_r_t = curr_r.iloc[:,3:].stack()
        curr_r_t = curr_r_t.reset_index()
        curr_r_t['CODE'] = curr_r_ind
        curr_r_t.columns = ['index','year','GDP','CODE']
        curr_r_t.drop(columns=['index'],inplace=True)

        curr_r1_ind = curr_r1['CODE']
        curr_r1_ind = np.tile(curr_r1_ind,21)
        curr_r1_t = curr_r1.iloc[:,3:].stack()
        curr_r1_t = curr_r1_t.reset_index()
        curr_r1_t['CODE'] = curr_r1_ind
        curr_r1_t.columns = ['index','year','GDP','CODE']
        curr_r1_t.drop(columns=['index'],inplace=True)

        curr_r_t['GDP'] = curr_r_t['GDP'].apply(lambda x: float(x.strip()))
        curr_r1_t['GDP'] = curr_r1_t['GDP'].apply(lambda x: float(x.strip()))
        curr_r_GDP_sum = curr_r_t.groupby(by = 'year')['GDP'].sum()
        curr_r1_GDP_sum = curr_r1_t.groupby(by = 'year')['GDP'].sum()
        
        curr_r_t = pd.merge(curr_r_t,curr_r_GDP_sum,left_on='year',right_index=True,suffixes=('','_tot'))
        curr_r_t['share'] = curr_r_t['GDP']/curr_r_t['GDP_tot']
        curr_r1_t = pd.merge(curr_r1_t,curr_r1_GDP_sum,left_on='year',right_index=True,suffixes=('','_tot'))
        curr_r1_t['share'] = curr_r1_t['GDP']/curr_r1_t['GDP_tot']

        curr_t = pd.merge(curr_r_t,curr_r1_t,how='outer',on = ['year','CODE'])
        curr_t[['share_x','share_y']] = curr_t[['share_x','share_y']].fillna(0.0)
        curr_t['GDP_diff'] = curr_t.apply(lambda row: (row['share_x']-row['share_y'])**2,axis=1)

        curr_t = curr_t.groupby('year')['GDP_diff'].sum()
        curr_t = curr_t.apply(lambda x:np.sqrt(x))

        curr_t = curr_t.reset_index()
        curr_t['Acquiror State']=r
        curr_t['Target State'] = r1

        industry_df = pd.concat([industry_df,curr_t])
        print('Finished ',r,' and ',r1)
print('END!!!')

industry_df = industry_df[~industry_df['Acquiror State'].isin(['UNITED STATES',
       'NEW ENGLAND', 'MIDEAST', 'GREAT LAKES', 'PLAINS', 'SOUTHEAST',
       'SOUTHWEST', 'ROCKY MTN', 'FAR WEST'])]
industry_df = industry_df[~industry_df['Target State'].isin(['UNITED STATES',
       'NEW ENGLAND', 'MIDEAST', 'GREAT LAKES', 'PLAINS', 'SOUTHEAST',
       'SOUTHWEST', 'ROCKY MTN', 'FAR WEST'])]
industry_df['year'] = industry_df['year'].astype(int)
industry_df.rename(columns={'GDP_diff':'Industry_dissimilarity_B-A'},inplace=True)
reg_df = pd.merge(reg_df,industry_df, left_on=['Acquiror State','Target State','announce_year'],right_on = ['Acquiror State','Target State','year'])
# Out:
# Finished  Alabama  and  Alaska
# Finished  Alabama  and  Arizona
# Finished  Alabama  and  Arkansas
# Finished  Alabama  and  California
# Finished  Alabama  and  Colorado
# Finished  Alabama  and  Connecticut
# Finished  Alabama  and  Delaware
# Finished  Alabama  and  D. of Columbia
# Finished  Alabama  and  Florida
# Finished  Alabama  and  Georgia
# Finished  Alabama  and  Hawaii
# Finished  Alabama  and  Idaho
# Finished  Alabama  and  Illinois
# Finished  Alabama  and  Indiana
# Finished  Alabama  and  Iowa
# Finished  Alabama  and  Kansas
# Finished  Alabama  and  Kentucky
# Finished  Alabama  and  Louisiana
# Finished  Alabama  and  Maine
# Finished  Alabama  and  Maryland
# Finished  Alabama  and  Massachusetts
# Finished  Alabama  and  Michigan
# Finished  Alabama  and  Minnesota
# Finished  Alabama  and  Mississippi
# Finished  Alabama  and  Missouri
# Finished  Alabama  and  Montana
# Finished  Alabama  and  Nebraska
# Finished  Alabama  and  Nevada
# Finished  Alabama  and  New Hampshire
# Finished  Alabama  and  New Jersey
# Finished  Alabama  and  New Mexico
# Finished  Alabama  and  New York
# Finished  Alabama  and  North Carolina
# Finished  Alabama  and  North Dakota
# Finished  Alabama  and  Ohio
# Finished  Alabama  and  Oklahoma
# Finished  Alabama  and  Oregon
# Finished  Alabama  and  Pennsylvania
# Finished  Alabama  and  Rhode Island
# Finished  Alabama  and  South Carolina
# Finished  Alabama  and  South Dakota
# Finished  Alabama  and  Tennessee
# Finished  Alabama  and  Texas
# Finished  Alabama  and  Utah
# Finished  Alabama  and  Vermont
# Finished  Alabama  and  Virginia
# Finished  Alabama  and  Washington
# Finished  Alabama  and  West Virginia
# Finished  Alabama  and  Wisconsin
# Finished  Alabama  and  Wyoming
# Finished  Alabama  and  UNITED STATES
# Finished  Alabama  and  NEW ENGLAND
# Finished  Alabama  and  MIDEAST
# Finished  Alabama  and  GREAT LAKES
# Finished  Alabama  and  PLAINS
# Finished  Alabama  and  SOUTHEAST
# Finished  Alabama  and  SOUTHWEST
# Finished  Alabama  and  ROCKY MTN
# Finished  Alabama  and  FAR WEST
# Finished  Alaska  and  Alabama
# Finished  Alaska  and  Arizona
# Finished  Alaska  and  Arkansas
# Finished  Alaska  and  California
# Finished  Alaska  and  Colorado
# Finished  Alaska  and  Connecticut
# Finished  Alaska  and  Delaware
# Finished  Alaska  and  D. of Columbia
# Finished  Alaska  and  Florida
# Finished  Alaska  and  Georgia
# Finished  Alaska  and  Hawaii
# Finished  Alaska  and  Idaho
# Finished  Alaska  and  Illinois
# Finished  Alaska  and  Indiana
# Finished  Alaska  and  Iowa
# Finished  Alaska  and  Kansas
# Finished  Alaska  and  Kentucky
# Finished  Alaska  and  Louisiana
# Finished  Alaska  and  Maine
# Finished  Alaska  and  Maryland
# Finished  Alaska  and  Massachusetts
# Finished  Alaska  and  Michigan
# Finished  Alaska  and  Minnesota
# Finished  Alaska  and  Mississippi
# Finished  Alaska  and  Missouri
# Finished  Alaska  and  Montana
# Finished  Alaska  and  Nebraska
# Finished  Alaska  and  Nevada
# Finished  Alaska  and  New Hampshire
# Finished  Alaska  and  New Jersey
# Finished  Alaska  and  New Mexico
# Finished  Alaska  and  New York
# Finished  Alaska  and  North Carolina
# Finished  Alaska  and  North Dakota
# Finished  Alaska  and  Ohio
# Finished  Alaska  and  Oklahoma
# Finished  Alaska  and  Oregon
# Finished  Alaska  and  Pennsylvania
# Finished  Alaska  and  Rhode Island
# Finished  Alaska  and  South Carolina
# Finished  Alaska  and  South Dakota
# Finished  Alaska  and  Tennessee
# Finished  Alaska  and  Texas
# Finished  Alaska  and  Utah
# Finished  Alaska  and  Vermont
# Finished  Alaska  and  Virginia
# Finished  Alaska  and  Washington
# Finished  Alaska  and  West Virginia
# Finished  Alaska  and  Wisconsin
# Finished  Alaska  and  Wyoming
# Finished  Alaska  and  UNITED STATES
# Finished  Alaska  and  NEW ENGLAND
# Finished  Alaska  and  MIDEAST
# Finished  Alaska  and  GREAT LAKES
# Finished  Alaska  and  PLAINS
# Finished  Alaska  and  SOUTHEAST
# Finished  Alaska  and  SOUTHWEST
# Finished  Alaska  and  ROCKY MTN
# Finished  Alaska  and  FAR WEST
# Finished  Arizona  and  Alabama
# Finished  Arizona  and  Alaska
# Finished  Arizona  and  Arkansas
# Finished  Arizona  and  California
# Finished  Arizona  and  Colorado
# Finished  Arizona  and  Connecticut
# Finished  Arizona  and  Delaware
# Finished  Arizona  and  D. of Columbia
# Finished  Arizona  and  Florida
# Finished  Arizona  and  Georgia
# Finished  Arizona  and  Hawaii
# Finished  Arizona  and  Idaho
# Finished  Arizona  and  Illinois
# Finished  Arizona  and  Indiana
# Finished  Arizona  and  Iowa
# Finished  Arizona  and  Kansas
# Finished  Arizona  and  Kentucky
# Finished  Arizona  and  Louisiana
# Finished  Arizona  and  Maine
# Finished  Arizona  and  Maryland
# Finished  Arizona  and  Massachusetts
# Finished  Arizona  and  Michigan
# Finished  Arizona  and  Minnesota
# Finished  Arizona  and  Mississippi
# Finished  Arizona  and  Missouri
# Finished  Arizona  and  Montana
# Finished  Arizona  and  Nebraska
# Finished  Arizona  and  Nevada
# Finished  Arizona  and  New Hampshire
# Finished  Arizona  and  New Jersey
# Finished  Arizona  and  New Mexico
# Finished  Arizona  and  New York
# Finished  Arizona  and  North Carolina
# Finished  Arizona  and  North Dakota
# Finished  Arizona  and  Ohio
# Finished  Arizona  and  Oklahoma
# Finished  Arizona  and  Oregon
# Finished  Arizona  and  Pennsylvania
# Finished  Arizona  and  Rhode Island
# Finished  Arizona  and  South Carolina
# Finished  Arizona  and  South Dakota
# Finished  Arizona  and  Tennessee
# Finished  Arizona  and  Texas
# Finished  Arizona  and  Utah
# Finished  Arizona  and  Vermont
# Finished  Arizona  and  Virginia
# Finished  Arizona  and  Washington
# Finished  Arizona  and  West Virginia
# Finished  Arizona  and  Wisconsin
# Finished  Arizona  and  Wyoming
# Finished  Arizona  and  UNITED STATES
# Finished  Arizona  and  NEW ENGLAND
# Finished  Arizona  and  MIDEAST
# Finished  Arizona  and  GREAT LAKES
# Finished  Arizona  and  PLAINS
# Finished  Arizona  and  SOUTHEAST
# Finished  Arizona  and  SOUTHWEST
# Finished  Arizona  and  ROCKY MTN
# Finished  Arizona  and  FAR WEST
# Finished  Arkansas  and  Alabama
# Finished  Arkansas  and  Alaska
# Finished  Arkansas  and  Arizona
# Finished  Arkansas  and  California
# Finished  Arkansas  and  Colorado
# Finished  Arkansas  and  Connecticut
# Finished  Arkansas  and  Delaware
# Finished  Arkansas  and  D. of Columbia
# Finished  Arkansas  and  Florida
# Finished  Arkansas  and  Georgia
# Finished  Arkansas  and  Hawaii
# Finished  Arkansas  and  Idaho
# Finished  Arkansas  and  Illinois
# Finished  Arkansas  and  Indiana
# Finished  Arkansas  and  Iowa
# Finished  Arkansas  and  Kansas
# Finished  Arkansas  and  Kentucky
# Finished  Arkansas  and  Louisiana
# Finished  Arkansas  and  Maine
# Finished  Arkansas  and  Maryland
# Finished  Arkansas  and  Massachusetts
# Finished  Arkansas  and  Michigan
# Finished  Arkansas  and  Minnesota
# Finished  Arkansas  and  Mississippi
# Finished  Arkansas  and  Missouri
# Finished  Arkansas  and  Montana
# Finished  Arkansas  and  Nebraska
# Finished  Arkansas  and  Nevada
# Finished  Arkansas  and  New Hampshire
# Finished  Arkansas  and  New Jersey
# Finished  Arkansas  and  New Mexico
# Finished  Arkansas  and  New York
# Finished  Arkansas  and  North Carolina
# Finished  Arkansas  and  North Dakota
# Finished  Arkansas  and  Ohio
# Finished  Arkansas  and  Oklahoma
# Finished  Arkansas  and  Oregon
# Finished  Arkansas  and  Pennsylvania
# Finished  Arkansas  and  Rhode Island
# Finished  Arkansas  and  South Carolina
# Finished  Arkansas  and  South Dakota
# Finished  Arkansas  and  Tennessee
# Finished  Arkansas  and  Texas
# Finished  Arkansas  and  Utah
# Finished  Arkansas  and  Vermont
# Finished  Arkansas  and  Virginia
# Finished  Arkansas  and  Washington
# Finished  Arkansas  and  West Virginia
# Finished  Arkansas  and  Wisconsin
# Finished  Arkansas  and  Wyoming
# Finished  Arkansas  and  UNITED STATES
# Finished  Arkansas  and  NEW ENGLAND
# Finished  Arkansas  and  MIDEAST
# Finished  Arkansas  and  GREAT LAKES
# Finished  Arkansas  and  PLAINS
# Finished  Arkansas  and  SOUTHEAST
# Finished  Arkansas  and  SOUTHWEST
# Finished  Arkansas  and  ROCKY MTN
# Finished  Arkansas  and  FAR WEST
# Finished  California  and  Alabama
# Finished  California  and  Alaska
# Finished  California  and  Arizona
# Finished  California  and  Arkansas
# Finished  California  and  Colorado
# Finished  California  and  Connecticut
# Finished  California  and  Delaware
# Finished  California  and  D. of Columbia
# Finished  California  and  Florida
# Finished  California  and  Georgia
# Finished  California  and  Hawaii
# Finished  California  and  Idaho
# Finished  California  and  Illinois
# Finished  California  and  Indiana
# Finished  California  and  Iowa
# Finished  California  and  Kansas
# Finished  California  and  Kentucky
# Finished  California  and  Louisiana
# Finished  California  and  Maine
# Finished  California  and  Maryland
# Finished  California  and  Massachusetts
# Finished  California  and  Michigan
# Finished  California  and  Minnesota
# Finished  California  and  Mississippi
# Finished  California  and  Missouri
# Finished  California  and  Montana
# Finished  California  and  Nebraska
# Finished  California  and  Nevada
# Finished  California  and  New Hampshire
# Finished  California  and  New Jersey
# Finished  California  and  New Mexico
# Finished  California  and  New York
# Finished  California  and  North Carolina
# Finished  California  and  North Dakota
# Finished  California  and  Ohio
# Finished  California  and  Oklahoma
# Finished  California  and  Oregon
# Finished  California  and  Pennsylvania
# Finished  California  and  Rhode Island
# Finished  California  and  South Carolina
# Finished  California  and  South Dakota
# Finished  California  and  Tennessee
# Finished  California  and  Texas
# Finished  California  and  Utah
# Finished  California  and  Vermont
# Finished  California  and  Virginia
# Finished  California  and  Washington
# Finished  California  and  West Virginia
# Finished  California  and  Wisconsin
# Finished  California  and  Wyoming
# Finished  California  and  UNITED STATES
# Finished  California  and  NEW ENGLAND
# Finished  California  and  MIDEAST
# Finished  California  and  GREAT LAKES
# Finished  California  and  PLAINS
# Finished  California  and  SOUTHEAST
# Finished  California  and  SOUTHWEST
# Finished  California  and  ROCKY MTN
# Finished  California  and  FAR WEST
# Finished  Colorado  and  Alabama
# Finished  Colorado  and  Alaska
# Finished  Colorado  and  Arizona
# Finished  Colorado  and  Arkansas
# Finished  Colorado  and  California
# Finished  Colorado  and  Connecticut
# Finished  Colorado  and  Delaware
# Finished  Colorado  and  D. of Columbia
# Finished  Colorado  and  Florida
# Finished  Colorado  and  Georgia
# Finished  Colorado  and  Hawaii
# Finished  Colorado  and  Idaho
# Finished  Colorado  and  Illinois
# Finished  Colorado  and  Indiana
# Finished  Colorado  and  Iowa
# Finished  Colorado  and  Kansas
# Finished  Colorado  and  Kentucky
# Finished  Colorado  and  Louisiana
# Finished  Colorado  and  Maine
# Finished  Colorado  and  Maryland
# Finished  Colorado  and  Massachusetts
# Finished  Colorado  and  Michigan
# Finished  Colorado  and  Minnesota
# Finished  Colorado  and  Mississippi
# Finished  Colorado  and  Missouri
# Finished  Colorado  and  Montana
# Finished  Colorado  and  Nebraska
# Finished  Colorado  and  Nevada
# Finished  Colorado  and  New Hampshire
# Finished  Colorado  and  New Jersey
# Finished  Colorado  and  New Mexico
# Finished  Colorado  and  New York
# Finished  Colorado  and  North Carolina
# Finished  Colorado  and  North Dakota
# Finished  Colorado  and  Ohio
# Finished  Colorado  and  Oklahoma
# Finished  Colorado  and  Oregon
# Finished  Colorado  and  Pennsylvania
# Finished  Colorado  and  Rhode Island
# Finished  Colorado  and  South Carolina
# Finished  Colorado  and  South Dakota
# Finished  Colorado  and  Tennessee
# Finished  Colorado  and  Texas
# Finished  Colorado  and  Utah
# Finished  Colorado  and  Vermont
# Finished  Colorado  and  Virginia
# Finished  Colorado  and  Washington
# Finished  Colorado  and  West Virginia
# Finished  Colorado  and  Wisconsin
# Finished  Colorado  and  Wyoming
# Finished  Colorado  and  UNITED STATES
# Finished  Colorado  and  NEW ENGLAND
# Finished  Colorado  and  MIDEAST
# Finished  Colorado  and  GREAT LAKES
# Finished  Colorado  and  PLAINS
# Finished  Colorado  and  SOUTHEAST
# Finished  Colorado  and  SOUTHWEST
# Finished  Colorado  and  ROCKY MTN
# Finished  Colorado  and  FAR WEST
# Finished  Connecticut  and  Alabama
# Finished  Connecticut  and  Alaska
# Finished  Connecticut  and  Arizona
# Finished  Connecticut  and  Arkansas
# Finished  Connecticut  and  California
# Finished  Connecticut  and  Colorado
# Finished  Connecticut  and  Delaware
# Finished  Connecticut  and  D. of Columbia
# Finished  Connecticut  and  Florida
# Finished  Connecticut  and  Georgia
# Finished  Connecticut  and  Hawaii
# Finished  Connecticut  and  Idaho
# Finished  Connecticut  and  Illinois
# Finished  Connecticut  and  Indiana
# Finished  Connecticut  and  Iowa
# Finished  Connecticut  and  Kansas
# Finished  Connecticut  and  Kentucky
# Finished  Connecticut  and  Louisiana
# Finished  Connecticut  and  Maine
# Finished  Connecticut  and  Maryland
# Finished  Connecticut  and  Massachusetts
# Finished  Connecticut  and  Michigan
# Finished  Connecticut  and  Minnesota
# Finished  Connecticut  and  Mississippi
# Finished  Connecticut  and  Missouri
# Finished  Connecticut  and  Montana
# Finished  Connecticut  and  Nebraska
# Finished  Connecticut  and  Nevada
# Finished  Connecticut  and  New Hampshire
# Finished  Connecticut  and  New Jersey
# Finished  Connecticut  and  New Mexico
# Finished  Connecticut  and  New York
# Finished  Connecticut  and  North Carolina
# Finished  Connecticut  and  North Dakota
# Finished  Connecticut  and  Ohio
# Finished  Connecticut  and  Oklahoma
# Finished  Connecticut  and  Oregon
# Finished  Connecticut  and  Pennsylvania
# Finished  Connecticut  and  Rhode Island
# Finished  Connecticut  and  South Carolina
# Finished  Connecticut  and  South Dakota
# Finished  Connecticut  and  Tennessee
# Finished  Connecticut  and  Texas
# Finished  Connecticut  and  Utah
# Finished  Connecticut  and  Vermont
# Finished  Connecticut  and  Virginia
# Finished  Connecticut  and  Washington
# Finished  Connecticut  and  West Virginia
# Finished  Connecticut  and  Wisconsin
# Finished  Connecticut  and  Wyoming
# Finished  Connecticut  and  UNITED STATES
# Finished  Connecticut  and  NEW ENGLAND
# Finished  Connecticut  and  MIDEAST
# Finished  Connecticut  and  GREAT LAKES
# Finished  Connecticut  and  PLAINS
# Finished  Connecticut  and  SOUTHEAST
# Finished  Connecticut  and  SOUTHWEST
# Finished  Connecticut  and  ROCKY MTN
# Finished  Connecticut  and  FAR WEST
# Finished  Delaware  and  Alabama
# Finished  Delaware  and  Alaska
# Finished  Delaware  and  Arizona
# Finished  Delaware  and  Arkansas
# Finished  Delaware  and  California
# Finished  Delaware  and  Colorado
# Finished  Delaware  and  Connecticut
# Finished  Delaware  and  D. of Columbia
# Finished  Delaware  and  Florida
# Finished  Delaware  and  Georgia
# Finished  Delaware  and  Hawaii
# Finished  Delaware  and  Idaho
# Finished  Delaware  and  Illinois
# Finished  Delaware  and  Indiana
# Finished  Delaware  and  Iowa
# Finished  Delaware  and  Kansas
# Finished  Delaware  and  Kentucky
# Finished  Delaware  and  Louisiana
# Finished  Delaware  and  Maine
# Finished  Delaware  and  Maryland
# Finished  Delaware  and  Massachusetts
# Finished  Delaware  and  Michigan
# Finished  Delaware  and  Minnesota
# Finished  Delaware  and  Mississippi
# Finished  Delaware  and  Missouri
# Finished  Delaware  and  Montana
# Finished  Delaware  and  Nebraska
# Finished  Delaware  and  Nevada
# Finished  Delaware  and  New Hampshire
# Finished  Delaware  and  New Jersey
# Finished  Delaware  and  New Mexico
# Finished  Delaware  and  New York
# Finished  Delaware  and  North Carolina
# Finished  Delaware  and  North Dakota
# Finished  Delaware  and  Ohio
# Finished  Delaware  and  Oklahoma
# Finished  Delaware  and  Oregon
# Finished  Delaware  and  Pennsylvania
# Finished  Delaware  and  Rhode Island
# Finished  Delaware  and  South Carolina
# Finished  Delaware  and  South Dakota
# Finished  Delaware  and  Tennessee
# Finished  Delaware  and  Texas
# Finished  Delaware  and  Utah
# Finished  Delaware  and  Vermont
# Finished  Delaware  and  Virginia
# Finished  Delaware  and  Washington
# Finished  Delaware  and  West Virginia
# Finished  Delaware  and  Wisconsin
# Finished  Delaware  and  Wyoming
# Finished  Delaware  and  UNITED STATES
# Finished  Delaware  and  NEW ENGLAND
# Finished  Delaware  and  MIDEAST
# Finished  Delaware  and  GREAT LAKES
# Finished  Delaware  and  PLAINS
# Finished  Delaware  and  SOUTHEAST
# Finished  Delaware  and  SOUTHWEST
# Finished  Delaware  and  ROCKY MTN
# Finished  Delaware  and  FAR WEST
# Finished  D. of Columbia  and  Alabama
# Finished  D. of Columbia  and  Alaska
# Finished  D. of Columbia  and  Arizona
# Finished  D. of Columbia  and  Arkansas
# Finished  D. of Columbia  and  California
# Finished  D. of Columbia  and  Colorado
# Finished  D. of Columbia  and  Connecticut
# Finished  D. of Columbia  and  Delaware
# Finished  D. of Columbia  and  Florida
# Finished  D. of Columbia  and  Georgia
# Finished  D. of Columbia  and  Hawaii
# Finished  D. of Columbia  and  Idaho
# Finished  D. of Columbia  and  Illinois
# Finished  D. of Columbia  and  Indiana
# Finished  D. of Columbia  and  Iowa
# Finished  D. of Columbia  and  Kansas
# Finished  D. of Columbia  and  Kentucky
# Finished  D. of Columbia  and  Louisiana
# Finished  D. of Columbia  and  Maine
# Finished  D. of Columbia  and  Maryland
# Finished  D. of Columbia  and  Massachusetts
# Finished  D. of Columbia  and  Michigan
# Finished  D. of Columbia  and  Minnesota
# Finished  D. of Columbia  and  Mississippi
# Finished  D. of Columbia  and  Missouri
# Finished  D. of Columbia  and  Montana
# Finished  D. of Columbia  and  Nebraska
# Finished  D. of Columbia  and  Nevada
# Finished  D. of Columbia  and  New Hampshire
# Finished  D. of Columbia  and  New Jersey
# Finished  D. of Columbia  and  New Mexico
# Finished  D. of Columbia  and  New York
# Finished  D. of Columbia  and  North Carolina
# Finished  D. of Columbia  and  North Dakota
# Finished  D. of Columbia  and  Ohio
# Finished  D. of Columbia  and  Oklahoma
# Finished  D. of Columbia  and  Oregon
# Finished  D. of Columbia  and  Pennsylvania
# Finished  D. of Columbia  and  Rhode Island
# Finished  D. of Columbia  and  South Carolina
# Finished  D. of Columbia  and  South Dakota
# Finished  D. of Columbia  and  Tennessee
# Finished  D. of Columbia  and  Texas
# Finished  D. of Columbia  and  Utah
# Finished  D. of Columbia  and  Vermont
# Finished  D. of Columbia  and  Virginia
# Finished  D. of Columbia  and  Washington
# Finished  D. of Columbia  and  West Virginia
# Finished  D. of Columbia  and  Wisconsin
# Finished  D. of Columbia  and  Wyoming
# Finished  D. of Columbia  and  UNITED STATES
# Finished  D. of Columbia  and  NEW ENGLAND
# Finished  D. of Columbia  and  MIDEAST
# Finished  D. of Columbia  and  GREAT LAKES
# Finished  D. of Columbia  and  PLAINS
# Finished  D. of Columbia  and  SOUTHEAST
# Finished  D. of Columbia  and  SOUTHWEST
# Finished  D. of Columbia  and  ROCKY MTN
# Finished  D. of Columbia  and  FAR WEST
# Finished  Florida  and  Alabama
# Finished  Florida  and  Alaska
# Finished  Florida  and  Arizona
# Finished  Florida  and  Arkansas
# Finished  Florida  and  California
# Finished  Florida  and  Colorado
# Finished  Florida  and  Connecticut
# Finished  Florida  and  Delaware
# Finished  Florida  and  D. of Columbia
# Finished  Florida  and  Georgia
# Finished  Florida  and  Hawaii
# Finished  Florida  and  Idaho
# Finished  Florida  and  Illinois
# Finished  Florida  and  Indiana
# Finished  Florida  and  Iowa
# Finished  Florida  and  Kansas
# Finished  Florida  and  Kentucky
# Finished  Florida  and  Louisiana
# Finished  Florida  and  Maine
# Finished  Florida  and  Maryland
# Finished  Florida  and  Massachusetts
# Finished  Florida  and  Michigan
# Finished  Florida  and  Minnesota
# Finished  Florida  and  Mississippi
# Finished  Florida  and  Missouri
# Finished  Florida  and  Montana
# Finished  Florida  and  Nebraska
# Finished  Florida  and  Nevada
# Finished  Florida  and  New Hampshire
# Finished  Florida  and  New Jersey
# Finished  Florida  and  New Mexico
# Finished  Florida  and  New York
# Finished  Florida  and  North Carolina
# Finished  Florida  and  North Dakota
# Finished  Florida  and  Ohio
# Finished  Florida  and  Oklahoma
# Finished  Florida  and  Oregon
# Finished  Florida  and  Pennsylvania
# Finished  Florida  and  Rhode Island
# Finished  Florida  and  South Carolina
# Finished  Florida  and  South Dakota
# Finished  Florida  and  Tennessee
# Finished  Florida  and  Texas
# Finished  Florida  and  Utah
# Finished  Florida  and  Vermont
# Finished  Florida  and  Virginia
# Finished  Florida  and  Washington
# Finished  Florida  and  West Virginia
# Finished  Florida  and  Wisconsin
# Finished  Florida  and  Wyoming
# Finished  Florida  and  UNITED STATES
# Finished  Florida  and  NEW ENGLAND
# Finished  Florida  and  MIDEAST
# Finished  Florida  and  GREAT LAKES
# Finished  Florida  and  PLAINS
# Finished  Florida  and  SOUTHEAST
# Finished  Florida  and  SOUTHWEST
# Finished  Florida  and  ROCKY MTN
# Finished  Florida  and  FAR WEST
# Finished  Georgia  and  Alabama
# Finished  Georgia  and  Alaska
# Finished  Georgia  and  Arizona
# Finished  Georgia  and  Arkansas
# Finished  Georgia  and  California
# Finished  Georgia  and  Colorado
# Finished  Georgia  and  Connecticut
# Finished  Georgia  and  Delaware
# Finished  Georgia  and  D. of Columbia
# Finished  Georgia  and  Florida
# Finished  Georgia  and  Hawaii
# Finished  Georgia  and  Idaho
# Finished  Georgia  and  Illinois
# Finished  Georgia  and  Indiana
# Finished  Georgia  and  Iowa
# Finished  Georgia  and  Kansas
# Finished  Georgia  and  Kentucky
# Finished  Georgia  and  Louisiana
# Finished  Georgia  and  Maine
# Finished  Georgia  and  Maryland
# Finished  Georgia  and  Massachusetts
# Finished  Georgia  and  Michigan
# Finished  Georgia  and  Minnesota
# Finished  Georgia  and  Mississippi
# Finished  Georgia  and  Missouri
# Finished  Georgia  and  Montana
# Finished  Georgia  and  Nebraska
# Finished  Georgia  and  Nevada
# Finished  Georgia  and  New Hampshire
# Finished  Georgia  and  New Jersey
# Finished  Georgia  and  New Mexico
# Finished  Georgia  and  New York
# Finished  Georgia  and  North Carolina
# Finished  Georgia  and  North Dakota
# Finished  Georgia  and  Ohio
# Finished  Georgia  and  Oklahoma
# Finished  Georgia  and  Oregon
# Finished  Georgia  and  Pennsylvania
# Finished  Georgia  and  Rhode Island
# Finished  Georgia  and  South Carolina
# Finished  Georgia  and  South Dakota
# Finished  Georgia  and  Tennessee
# Finished  Georgia  and  Texas
# Finished  Georgia  and  Utah
# Finished  Georgia  and  Vermont
# Finished  Georgia  and  Virginia
# Finished  Georgia  and  Washington
# Finished  Georgia  and  West Virginia
# Finished  Georgia  and  Wisconsin
# Finished  Georgia  and  Wyoming
# Finished  Georgia  and  UNITED STATES
# Finished  Georgia  and  NEW ENGLAND
# Finished  Georgia  and  MIDEAST
# Finished  Georgia  and  GREAT LAKES
# Finished  Georgia  and  PLAINS
# Finished  Georgia  and  SOUTHEAST
# Finished  Georgia  and  SOUTHWEST
# Finished  Georgia  and  ROCKY MTN
# Finished  Georgia  and  FAR WEST
# Finished  Hawaii  and  Alabama
# Finished  Hawaii  and  Alaska
# Finished  Hawaii  and  Arizona
# Finished  Hawaii  and  Arkansas
# Finished  Hawaii  and  California
# Finished  Hawaii  and  Colorado
# Finished  Hawaii  and  Connecticut
# Finished  Hawaii  and  Delaware
# Finished  Hawaii  and  D. of Columbia
# Finished  Hawaii  and  Florida
# Finished  Hawaii  and  Georgia
# Finished  Hawaii  and  Idaho
# Finished  Hawaii  and  Illinois
# Finished  Hawaii  and  Indiana
# Finished  Hawaii  and  Iowa
# Finished  Hawaii  and  Kansas
# Finished  Hawaii  and  Kentucky
# Finished  Hawaii  and  Louisiana
# Finished  Hawaii  and  Maine
# Finished  Hawaii  and  Maryland
# Finished  Hawaii  and  Massachusetts
# Finished  Hawaii  and  Michigan
# Finished  Hawaii  and  Minnesota
# Finished  Hawaii  and  Mississippi
# Finished  Hawaii  and  Missouri
# Finished  Hawaii  and  Montana
# Finished  Hawaii  and  Nebraska
# Finished  Hawaii  and  Nevada
# Finished  Hawaii  and  New Hampshire
# Finished  Hawaii  and  New Jersey
# Finished  Hawaii  and  New Mexico
# Finished  Hawaii  and  New York
# Finished  Hawaii  and  North Carolina
# Finished  Hawaii  and  North Dakota
# Finished  Hawaii  and  Ohio
# Finished  Hawaii  and  Oklahoma
# Finished  Hawaii  and  Oregon
# Finished  Hawaii  and  Pennsylvania
# Finished  Hawaii  and  Rhode Island
# Finished  Hawaii  and  South Carolina
# Finished  Hawaii  and  South Dakota
# Finished  Hawaii  and  Tennessee
# Finished  Hawaii  and  Texas
# Finished  Hawaii  and  Utah
# Finished  Hawaii  and  Vermont
# Finished  Hawaii  and  Virginia
# Finished  Hawaii  and  Washington
# Finished  Hawaii  and  West Virginia
# Finished  Hawaii  and  Wisconsin
# Finished  Hawaii  and  Wyoming
# Finished  Hawaii  and  UNITED STATES
# Finished  Hawaii  and  NEW ENGLAND
# Finished  Hawaii  and  MIDEAST
# Finished  Hawaii  and  GREAT LAKES
# Finished  Hawaii  and  PLAINS
# Finished  Hawaii  and  SOUTHEAST
# Finished  Hawaii  and  SOUTHWEST
# Finished  Hawaii  and  ROCKY MTN
# Finished  Hawaii  and  FAR WEST
# Finished  Idaho  and  Alabama
# Finished  Idaho  and  Alaska
# Finished  Idaho  and  Arizona
# Finished  Idaho  and  Arkansas
# Finished  Idaho  and  California
# Finished  Idaho  and  Colorado
# Finished  Idaho  and  Connecticut
# Finished  Idaho  and  Delaware
# Finished  Idaho  and  D. of Columbia
# Finished  Idaho  and  Florida
# Finished  Idaho  and  Georgia
# Finished  Idaho  and  Hawaii
# Finished  Idaho  and  Illinois
# Finished  Idaho  and  Indiana
# Finished  Idaho  and  Iowa
# Finished  Idaho  and  Kansas
# Finished  Idaho  and  Kentucky
# Finished  Idaho  and  Louisiana
# Finished  Idaho  and  Maine
# Finished  Idaho  and  Maryland
# Finished  Idaho  and  Massachusetts
# Finished  Idaho  and  Michigan
# Finished  Idaho  and  Minnesota
# Finished  Idaho  and  Mississippi
# Finished  Idaho  and  Missouri
# Finished  Idaho  and  Montana
# Finished  Idaho  and  Nebraska
# Finished  Idaho  and  Nevada
# Finished  Idaho  and  New Hampshire
# Finished  Idaho  and  New Jersey
# Finished  Idaho  and  New Mexico
# Finished  Idaho  and  New York
# Finished  Idaho  and  North Carolina
# Finished  Idaho  and  North Dakota
# Finished  Idaho  and  Ohio
# Finished  Idaho  and  Oklahoma
# Finished  Idaho  and  Oregon
# Finished  Idaho  and  Pennsylvania
# Finished  Idaho  and  Rhode Island
# Finished  Idaho  and  South Carolina
# Finished  Idaho  and  South Dakota
# Finished  Idaho  and  Tennessee
# Finished  Idaho  and  Texas
# Finished  Idaho  and  Utah
# Finished  Idaho  and  Vermont
# Finished  Idaho  and  Virginia
# Finished  Idaho  and  Washington
# Finished  Idaho  and  West Virginia
# Finished  Idaho  and  Wisconsin
# Finished  Idaho  and  Wyoming
# Finished  Idaho  and  UNITED STATES
# Finished  Idaho  and  NEW ENGLAND
# Finished  Idaho  and  MIDEAST
# Finished  Idaho  and  GREAT LAKES
# Finished  Idaho  and  PLAINS
# Finished  Idaho  and  SOUTHEAST
# Finished  Idaho  and  SOUTHWEST
# Finished  Idaho  and  ROCKY MTN
# Finished  Idaho  and  FAR WEST
# Finished  Illinois  and  Alabama
# Finished  Illinois  and  Alaska
# Finished  Illinois  and  Arizona
# Finished  Illinois  and  Arkansas
# Finished  Illinois  and  California
# Finished  Illinois  and  Colorado
# Finished  Illinois  and  Connecticut
# Finished  Illinois  and  Delaware
# Finished  Illinois  and  D. of Columbia
# Finished  Illinois  and  Florida
# Finished  Illinois  and  Georgia
# Finished  Illinois  and  Hawaii
# Finished  Illinois  and  Idaho
# Finished  Illinois  and  Indiana
# Finished  Illinois  and  Iowa
# Finished  Illinois  and  Kansas
# Finished  Illinois  and  Kentucky
# Finished  Illinois  and  Louisiana
# Finished  Illinois  and  Maine
# Finished  Illinois  and  Maryland
# Finished  Illinois  and  Massachusetts
# Finished  Illinois  and  Michigan
# Finished  Illinois  and  Minnesota
# Finished  Illinois  and  Mississippi
# Finished  Illinois  and  Missouri
# Finished  Illinois  and  Montana
# Finished  Illinois  and  Nebraska
# Finished  Illinois  and  Nevada
# Finished  Illinois  and  New Hampshire
# Finished  Illinois  and  New Jersey
# Finished  Illinois  and  New Mexico
# Finished  Illinois  and  New York
# Finished  Illinois  and  North Carolina
# Finished  Illinois  and  North Dakota
# Finished  Illinois  and  Ohio
# Finished  Illinois  and  Oklahoma
# Finished  Illinois  and  Oregon
# Finished  Illinois  and  Pennsylvania
# Finished  Illinois  and  Rhode Island
# Finished  Illinois  and  South Carolina
# Finished  Illinois  and  South Dakota
# Finished  Illinois  and  Tennessee
# Finished  Illinois  and  Texas
# Finished  Illinois  and  Utah
# Finished  Illinois  and  Vermont
# Finished  Illinois  and  Virginia
# Finished  Illinois  and  Washington
# Finished  Illinois  and  West Virginia
# Finished  Illinois  and  Wisconsin
# Finished  Illinois  and  Wyoming
# Finished  Illinois  and  UNITED STATES
# Finished  Illinois  and  NEW ENGLAND
# Finished  Illinois  and  MIDEAST
# Finished  Illinois  and  GREAT LAKES
# Finished  Illinois  and  PLAINS
# Finished  Illinois  and  SOUTHEAST
# Finished  Illinois  and  SOUTHWEST
# Finished  Illinois  and  ROCKY MTN
# Finished  Illinois  and  FAR WEST
# Finished  Indiana  and  Alabama
# Finished  Indiana  and  Alaska
# Finished  Indiana  and  Arizona
# Finished  Indiana  and  Arkansas
# Finished  Indiana  and  California
# Finished  Indiana  and  Colorado
# Finished  Indiana  and  Connecticut
# Finished  Indiana  and  Delaware
# Finished  Indiana  and  D. of Columbia
# Finished  Indiana  and  Florida
# Finished  Indiana  and  Georgia
# Finished  Indiana  and  Hawaii
# Finished  Indiana  and  Idaho
# Finished  Indiana  and  Illinois
# Finished  Indiana  and  Iowa
# Finished  Indiana  and  Kansas
# Finished  Indiana  and  Kentucky
# Finished  Indiana  and  Louisiana
# Finished  Indiana  and  Maine
# Finished  Indiana  and  Maryland
# Finished  Indiana  and  Massachusetts
# Finished  Indiana  and  Michigan
# Finished  Indiana  and  Minnesota
# Finished  Indiana  and  Mississippi
# Finished  Indiana  and  Missouri
# Finished  Indiana  and  Montana
# Finished  Indiana  and  Nebraska
# Finished  Indiana  and  Nevada
# Finished  Indiana  and  New Hampshire
# Finished  Indiana  and  New Jersey
# Finished  Indiana  and  New Mexico
# Finished  Indiana  and  New York
# Finished  Indiana  and  North Carolina
# Finished  Indiana  and  North Dakota
# Finished  Indiana  and  Ohio
# Finished  Indiana  and  Oklahoma
# Finished  Indiana  and  Oregon
# Finished  Indiana  and  Pennsylvania
# Finished  Indiana  and  Rhode Island
# Finished  Indiana  and  South Carolina
# Finished  Indiana  and  South Dakota
# Finished  Indiana  and  Tennessee
# Finished  Indiana  and  Texas
# Finished  Indiana  and  Utah
# Finished  Indiana  and  Vermont
# Finished  Indiana  and  Virginia
# Finished  Indiana  and  Washington
# Finished  Indiana  and  West Virginia
# Finished  Indiana  and  Wisconsin
# Finished  Indiana  and  Wyoming
# Finished  Indiana  and  UNITED STATES
# Finished  Indiana  and  NEW ENGLAND
# Finished  Indiana  and  MIDEAST
# Finished  Indiana  and  GREAT LAKES
# Finished  Indiana  and  PLAINS
# Finished  Indiana  and  SOUTHEAST
# Finished  Indiana  and  SOUTHWEST
# Finished  Indiana  and  ROCKY MTN
# Finished  Indiana  and  FAR WEST
# Finished  Iowa  and  Alabama
# Finished  Iowa  and  Alaska
# Finished  Iowa  and  Arizona
# Finished  Iowa  and  Arkansas
# Finished  Iowa  and  California
# Finished  Iowa  and  Colorado
# Finished  Iowa  and  Connecticut
# Finished  Iowa  and  Delaware
# Finished  Iowa  and  D. of Columbia
# Finished  Iowa  and  Florida
# Finished  Iowa  and  Georgia
# Finished  Iowa  and  Hawaii
# Finished  Iowa  and  Idaho
# Finished  Iowa  and  Illinois
# Finished  Iowa  and  Indiana
# Finished  Iowa  and  Kansas
# Finished  Iowa  and  Kentucky
# Finished  Iowa  and  Louisiana
# Finished  Iowa  and  Maine
# Finished  Iowa  and  Maryland
# Finished  Iowa  and  Massachusetts
# Finished  Iowa  and  Michigan
# Finished  Iowa  and  Minnesota
# Finished  Iowa  and  Mississippi
# Finished  Iowa  and  Missouri
# Finished  Iowa  and  Montana
# Finished  Iowa  and  Nebraska
# Finished  Iowa  and  Nevada
# Finished  Iowa  and  New Hampshire
# Finished  Iowa  and  New Jersey
# Finished  Iowa  and  New Mexico
# Finished  Iowa  and  New York
# Finished  Iowa  and  North Carolina
# Finished  Iowa  and  North Dakota
# Finished  Iowa  and  Ohio
# Finished  Iowa  and  Oklahoma
# Finished  Iowa  and  Oregon
# Finished  Iowa  and  Pennsylvania
# Finished  Iowa  and  Rhode Island
# Finished  Iowa  and  South Carolina
# Finished  Iowa  and  South Dakota
# Finished  Iowa  and  Tennessee
# Finished  Iowa  and  Texas
# Finished  Iowa  and  Utah
# Finished  Iowa  and  Vermont
# Finished  Iowa  and  Virginia
# Finished  Iowa  and  Washington
# Finished  Iowa  and  West Virginia
# Finished  Iowa  and  Wisconsin
# Finished  Iowa  and  Wyoming
# Finished  Iowa  and  UNITED STATES
# Finished  Iowa  and  NEW ENGLAND
# Finished  Iowa  and  MIDEAST
# Finished  Iowa  and  GREAT LAKES
# Finished  Iowa  and  PLAINS
# Finished  Iowa  and  SOUTHEAST
# Finished  Iowa  and  SOUTHWEST
# Finished  Iowa  and  ROCKY MTN
# Finished  Iowa  and  FAR WEST
# Finished  Kansas  and  Alabama
# Finished  Kansas  and  Alaska
# Finished  Kansas  and  Arizona
# Finished  Kansas  and  Arkansas
# Finished  Kansas  and  California
# Finished  Kansas  and  Colorado
# Finished  Kansas  and  Connecticut
# Finished  Kansas  and  Delaware
# Finished  Kansas  and  D. of Columbia
# Finished  Kansas  and  Florida
# Finished  Kansas  and  Georgia
# Finished  Kansas  and  Hawaii
# Finished  Kansas  and  Idaho
# Finished  Kansas  and  Illinois
# Finished  Kansas  and  Indiana
# Finished  Kansas  and  Iowa
# Finished  Kansas  and  Kentucky
# Finished  Kansas  and  Louisiana
# Finished  Kansas  and  Maine
# Finished  Kansas  and  Maryland
# Finished  Kansas  and  Massachusetts
# Finished  Kansas  and  Michigan
# Finished  Kansas  and  Minnesota
# Finished  Kansas  and  Mississippi
# Finished  Kansas  and  Missouri
# Finished  Kansas  and  Montana
# Finished  Kansas  and  Nebraska
# Finished  Kansas  and  Nevada
# Finished  Kansas  and  New Hampshire
# Finished  Kansas  and  New Jersey
# Finished  Kansas  and  New Mexico
# Finished  Kansas  and  New York
# Finished  Kansas  and  North Carolina
# Finished  Kansas  and  North Dakota
# Finished  Kansas  and  Ohio
# Finished  Kansas  and  Oklahoma
# Finished  Kansas  and  Oregon
# Finished  Kansas  and  Pennsylvania
# Finished  Kansas  and  Rhode Island
# Finished  Kansas  and  South Carolina
# Finished  Kansas  and  South Dakota
# Finished  Kansas  and  Tennessee
# Finished  Kansas  and  Texas
# Finished  Kansas  and  Utah
# Finished  Kansas  and  Vermont
# Finished  Kansas  and  Virginia
# Finished  Kansas  and  Washington
# Finished  Kansas  and  West Virginia
# Finished  Kansas  and  Wisconsin
# Finished  Kansas  and  Wyoming
# Finished  Kansas  and  UNITED STATES
# Finished  Kansas  and  NEW ENGLAND
# Finished  Kansas  and  MIDEAST
# Finished  Kansas  and  GREAT LAKES
# Finished  Kansas  and  PLAINS
# Finished  Kansas  and  SOUTHEAST
# Finished  Kansas  and  SOUTHWEST
# Finished  Kansas  and  ROCKY MTN
# Finished  Kansas  and  FAR WEST
# Finished  Kentucky  and  Alabama
# Finished  Kentucky  and  Alaska
# Finished  Kentucky  and  Arizona
# Finished  Kentucky  and  Arkansas
# Finished  Kentucky  and  California
# Finished  Kentucky  and  Colorado
# Finished  Kentucky  and  Connecticut
# Finished  Kentucky  and  Delaware
# Finished  Kentucky  and  D. of Columbia
# Finished  Kentucky  and  Florida
# Finished  Kentucky  and  Georgia
# Finished  Kentucky  and  Hawaii
# Finished  Kentucky  and  Idaho
# Finished  Kentucky  and  Illinois
# Finished  Kentucky  and  Indiana
# Finished  Kentucky  and  Iowa
# Finished  Kentucky  and  Kansas
# Finished  Kentucky  and  Louisiana
# Finished  Kentucky  and  Maine
# Finished  Kentucky  and  Maryland
# Finished  Kentucky  and  Massachusetts
# Finished  Kentucky  and  Michigan
# Finished  Kentucky  and  Minnesota
# Finished  Kentucky  and  Mississippi
# Finished  Kentucky  and  Missouri
# Finished  Kentucky  and  Montana
# Finished  Kentucky  and  Nebraska
# Finished  Kentucky  and  Nevada
# Finished  Kentucky  and  New Hampshire
# Finished  Kentucky  and  New Jersey
# Finished  Kentucky  and  New Mexico
# Finished  Kentucky  and  New York
# Finished  Kentucky  and  North Carolina
# Finished  Kentucky  and  North Dakota
# Finished  Kentucky  and  Ohio
# Finished  Kentucky  and  Oklahoma
# Finished  Kentucky  and  Oregon
# Finished  Kentucky  and  Pennsylvania
# Finished  Kentucky  and  Rhode Island
# Finished  Kentucky  and  South Carolina
# Finished  Kentucky  and  South Dakota
# Finished  Kentucky  and  Tennessee
# Finished  Kentucky  and  Texas
# Finished  Kentucky  and  Utah
# Finished  Kentucky  and  Vermont
# Finished  Kentucky  and  Virginia
# Finished  Kentucky  and  Washington
# Finished  Kentucky  and  West Virginia
# Finished  Kentucky  and  Wisconsin
# Finished  Kentucky  and  Wyoming
# Finished  Kentucky  and  UNITED STATES
# Finished  Kentucky  and  NEW ENGLAND
# Finished  Kentucky  and  MIDEAST
# Finished  Kentucky  and  GREAT LAKES
# Finished  Kentucky  and  PLAINS
# Finished  Kentucky  and  SOUTHEAST
# Finished  Kentucky  and  SOUTHWEST
# Finished  Kentucky  and  ROCKY MTN
# Finished  Kentucky  and  FAR WEST
# Finished  Louisiana  and  Alabama
# Finished  Louisiana  and  Alaska
# Finished  Louisiana  and  Arizona
# Finished  Louisiana  and  Arkansas
# Finished  Louisiana  and  California
# Finished  Louisiana  and  Colorado
# Finished  Louisiana  and  Connecticut
# Finished  Louisiana  and  Delaware
# Finished  Louisiana  and  D. of Columbia
# Finished  Louisiana  and  Florida
# Finished  Louisiana  and  Georgia
# Finished  Louisiana  and  Hawaii
# Finished  Louisiana  and  Idaho
# Finished  Louisiana  and  Illinois
# Finished  Louisiana  and  Indiana
# Finished  Louisiana  and  Iowa
# Finished  Louisiana  and  Kansas
# Finished  Louisiana  and  Kentucky
# Finished  Louisiana  and  Maine
# Finished  Louisiana  and  Maryland
# Finished  Louisiana  and  Massachusetts
# Finished  Louisiana  and  Michigan
# Finished  Louisiana  and  Minnesota
# Finished  Louisiana  and  Mississippi
# Finished  Louisiana  and  Missouri
# Finished  Louisiana  and  Montana
# Finished  Louisiana  and  Nebraska
# Finished  Louisiana  and  Nevada
# Finished  Louisiana  and  New Hampshire
# Finished  Louisiana  and  New Jersey
# Finished  Louisiana  and  New Mexico
# Finished  Louisiana  and  New York
# Finished  Louisiana  and  North Carolina
# Finished  Louisiana  and  North Dakota
# Finished  Louisiana  and  Ohio
# Finished  Louisiana  and  Oklahoma
# Finished  Louisiana  and  Oregon
# Finished  Louisiana  and  Pennsylvania
# Finished  Louisiana  and  Rhode Island
# Finished  Louisiana  and  South Carolina
# Finished  Louisiana  and  South Dakota
# Finished  Louisiana  and  Tennessee
# Finished  Louisiana  and  Texas
# Finished  Louisiana  and  Utah
# Finished  Louisiana  and  Vermont
# Finished  Louisiana  and  Virginia
# Finished  Louisiana  and  Washington
# Finished  Louisiana  and  West Virginia
# Finished  Louisiana  and  Wisconsin
# Finished  Louisiana  and  Wyoming
# Finished  Louisiana  and  UNITED STATES
# Finished  Louisiana  and  NEW ENGLAND
# Finished  Louisiana  and  MIDEAST
# Finished  Louisiana  and  GREAT LAKES
# Finished  Louisiana  and  PLAINS
# Finished  Louisiana  and  SOUTHEAST
# Finished  Louisiana  and  SOUTHWEST
# Finished  Louisiana  and  ROCKY MTN
# Finished  Louisiana  and  FAR WEST
# Finished  Maine  and  Alabama
# Finished  Maine  and  Alaska
# Finished  Maine  and  Arizona
# Finished  Maine  and  Arkansas
# Finished  Maine  and  California
# Finished  Maine  and  Colorado
# Finished  Maine  and  Connecticut
# Finished  Maine  and  Delaware
# Finished  Maine  and  D. of Columbia
# Finished  Maine  and  Florida
# Finished  Maine  and  Georgia
# Finished  Maine  and  Hawaii
# Finished  Maine  and  Idaho
# Finished  Maine  and  Illinois
# Finished  Maine  and  Indiana
# Finished  Maine  and  Iowa
# Finished  Maine  and  Kansas
# Finished  Maine  and  Kentucky
# Finished  Maine  and  Louisiana
# Finished  Maine  and  Maryland
# Finished  Maine  and  Massachusetts
# Finished  Maine  and  Michigan
# Finished  Maine  and  Minnesota
# Finished  Maine  and  Mississippi
# Finished  Maine  and  Missouri
# Finished  Maine  and  Montana
# Finished  Maine  and  Nebraska
# Finished  Maine  and  Nevada
# Finished  Maine  and  New Hampshire
# Finished  Maine  and  New Jersey
# Finished  Maine  and  New Mexico
# Finished  Maine  and  New York
# Finished  Maine  and  North Carolina
# Finished  Maine  and  North Dakota
# Finished  Maine  and  Ohio
# Finished  Maine  and  Oklahoma
# Finished  Maine  and  Oregon
# Finished  Maine  and  Pennsylvania
# Finished  Maine  and  Rhode Island
# Finished  Maine  and  South Carolina
# Finished  Maine  and  South Dakota
# Finished  Maine  and  Tennessee
# Finished  Maine  and  Texas
# Finished  Maine  and  Utah
# Finished  Maine  and  Vermont
# Finished  Maine  and  Virginia
# Finished  Maine  and  Washington
# Finished  Maine  and  West Virginia
# Finished  Maine  and  Wisconsin
# Finished  Maine  and  Wyoming
# Finished  Maine  and  UNITED STATES
# Finished  Maine  and  NEW ENGLAND
# Finished  Maine  and  MIDEAST
# Finished  Maine  and  GREAT LAKES
# Finished  Maine  and  PLAINS
# Finished  Maine  and  SOUTHEAST
# Finished  Maine  and  SOUTHWEST
# Finished  Maine  and  ROCKY MTN
# Finished  Maine  and  FAR WEST
# Finished  Maryland  and  Alabama
# Finished  Maryland  and  Alaska
# Finished  Maryland  and  Arizona
# Finished  Maryland  and  Arkansas
# Finished  Maryland  and  California
# Finished  Maryland  and  Colorado
# Finished  Maryland  and  Connecticut
# Finished  Maryland  and  Delaware
# Finished  Maryland  and  D. of Columbia
# Finished  Maryland  and  Florida
# Finished  Maryland  and  Georgia
# Finished  Maryland  and  Hawaii
# Finished  Maryland  and  Idaho
# Finished  Maryland  and  Illinois
# Finished  Maryland  and  Indiana
# Finished  Maryland  and  Iowa
# Finished  Maryland  and  Kansas
# Finished  Maryland  and  Kentucky
# Finished  Maryland  and  Louisiana
# Finished  Maryland  and  Maine
# Finished  Maryland  and  Massachusetts
# Finished  Maryland  and  Michigan
# Finished  Maryland  and  Minnesota
# Finished  Maryland  and  Mississippi
# Finished  Maryland  and  Missouri
# Finished  Maryland  and  Montana
# Finished  Maryland  and  Nebraska
# Finished  Maryland  and  Nevada
# Finished  Maryland  and  New Hampshire
# Finished  Maryland  and  New Jersey
# Finished  Maryland  and  New Mexico
# Finished  Maryland  and  New York
# Finished  Maryland  and  North Carolina
# Finished  Maryland  and  North Dakota
# Finished  Maryland  and  Ohio
# Finished  Maryland  and  Oklahoma
# Finished  Maryland  and  Oregon
# Finished  Maryland  and  Pennsylvania
# Finished  Maryland  and  Rhode Island
# Finished  Maryland  and  South Carolina
# Finished  Maryland  and  South Dakota
# Finished  Maryland  and  Tennessee
# Finished  Maryland  and  Texas
# Finished  Maryland  and  Utah
# Finished  Maryland  and  Vermont
# Finished  Maryland  and  Virginia
# Finished  Maryland  and  Washington
# Finished  Maryland  and  West Virginia
# Finished  Maryland  and  Wisconsin
# Finished  Maryland  and  Wyoming
# Finished  Maryland  and  UNITED STATES
# Finished  Maryland  and  NEW ENGLAND
# Finished  Maryland  and  MIDEAST
# Finished  Maryland  and  GREAT LAKES
# Finished  Maryland  and  PLAINS
# Finished  Maryland  and  SOUTHEAST
# Finished  Maryland  and  SOUTHWEST
# Finished  Maryland  and  ROCKY MTN
# Finished  Maryland  and  FAR WEST
# Finished  Massachusetts  and  Alabama
# Finished  Massachusetts  and  Alaska
# Finished  Massachusetts  and  Arizona
# Finished  Massachusetts  and  Arkansas
# Finished  Massachusetts  and  California
# Finished  Massachusetts  and  Colorado
# Finished  Massachusetts  and  Connecticut
# Finished  Massachusetts  and  Delaware
# Finished  Massachusetts  and  D. of Columbia
# Finished  Massachusetts  and  Florida
# Finished  Massachusetts  and  Georgia
# Finished  Massachusetts  and  Hawaii
# Finished  Massachusetts  and  Idaho
# Finished  Massachusetts  and  Illinois
# Finished  Massachusetts  and  Indiana
# Finished  Massachusetts  and  Iowa
# Finished  Massachusetts  and  Kansas
# Finished  Massachusetts  and  Kentucky
# Finished  Massachusetts  and  Louisiana
# Finished  Massachusetts  and  Maine
# Finished  Massachusetts  and  Maryland
# Finished  Massachusetts  and  Michigan
# Finished  Massachusetts  and  Minnesota
# Finished  Massachusetts  and  Mississippi
# Finished  Massachusetts  and  Missouri
# Finished  Massachusetts  and  Montana
# Finished  Massachusetts  and  Nebraska
# Finished  Massachusetts  and  Nevada
# Finished  Massachusetts  and  New Hampshire
# Finished  Massachusetts  and  New Jersey
# Finished  Massachusetts  and  New Mexico
# Finished  Massachusetts  and  New York
# Finished  Massachusetts  and  North Carolina
# Finished  Massachusetts  and  North Dakota
# Finished  Massachusetts  and  Ohio
# Finished  Massachusetts  and  Oklahoma
# Finished  Massachusetts  and  Oregon
# Finished  Massachusetts  and  Pennsylvania
# Finished  Massachusetts  and  Rhode Island
# Finished  Massachusetts  and  South Carolina
# Finished  Massachusetts  and  South Dakota
# Finished  Massachusetts  and  Tennessee
# Finished  Massachusetts  and  Texas
# Finished  Massachusetts  and  Utah
# Finished  Massachusetts  and  Vermont
# Finished  Massachusetts  and  Virginia
# Finished  Massachusetts  and  Washington
# Finished  Massachusetts  and  West Virginia
# Finished  Massachusetts  and  Wisconsin
# Finished  Massachusetts  and  Wyoming
# Finished  Massachusetts  and  UNITED STATES
# Finished  Massachusetts  and  NEW ENGLAND
# Finished  Massachusetts  and  MIDEAST
# Finished  Massachusetts  and  GREAT LAKES
# Finished  Massachusetts  and  PLAINS
# Finished  Massachusetts  and  SOUTHEAST
# Finished  Massachusetts  and  SOUTHWEST
# Finished  Massachusetts  and  ROCKY MTN
# Finished  Massachusetts  and  FAR WEST
# Finished  Michigan  and  Alabama
# Finished  Michigan  and  Alaska
# Finished  Michigan  and  Arizona
# Finished  Michigan  and  Arkansas
# Finished  Michigan  and  California
# Finished  Michigan  and  Colorado
# Finished  Michigan  and  Connecticut
# Finished  Michigan  and  Delaware
# Finished  Michigan  and  D. of Columbia
# Finished  Michigan  and  Florida
# Finished  Michigan  and  Georgia
# Finished  Michigan  and  Hawaii
# Finished  Michigan  and  Idaho
# Finished  Michigan  and  Illinois
# Finished  Michigan  and  Indiana
# Finished  Michigan  and  Iowa
# Finished  Michigan  and  Kansas
# Finished  Michigan  and  Kentucky
# Finished  Michigan  and  Louisiana
# Finished  Michigan  and  Maine
# Finished  Michigan  and  Maryland
# Finished  Michigan  and  Massachusetts
# Finished  Michigan  and  Minnesota
# Finished  Michigan  and  Mississippi
# Finished  Michigan  and  Missouri
# Finished  Michigan  and  Montana
# Finished  Michigan  and  Nebraska
# Finished  Michigan  and  Nevada
# Finished  Michigan  and  New Hampshire
# Finished  Michigan  and  New Jersey
# Finished  Michigan  and  New Mexico
# Finished  Michigan  and  New York
# Finished  Michigan  and  North Carolina
# Finished  Michigan  and  North Dakota
# Finished  Michigan  and  Ohio
# Finished  Michigan  and  Oklahoma
# Finished  Michigan  and  Oregon
# Finished  Michigan  and  Pennsylvania
# Finished  Michigan  and  Rhode Island
# Finished  Michigan  and  South Carolina
# Finished  Michigan  and  South Dakota
# Finished  Michigan  and  Tennessee
# Finished  Michigan  and  Texas
# Finished  Michigan  and  Utah
# Finished  Michigan  and  Vermont
# Finished  Michigan  and  Virginia
# Finished  Michigan  and  Washington
# Finished  Michigan  and  West Virginia
# Finished  Michigan  and  Wisconsin
# Finished  Michigan  and  Wyoming
# Finished  Michigan  and  UNITED STATES
# Finished  Michigan  and  NEW ENGLAND
# Finished  Michigan  and  MIDEAST
# Finished  Michigan  and  GREAT LAKES
# Finished  Michigan  and  PLAINS
# Finished  Michigan  and  SOUTHEAST
# Finished  Michigan  and  SOUTHWEST
# Finished  Michigan  and  ROCKY MTN
# Finished  Michigan  and  FAR WEST
# Finished  Minnesota  and  Alabama
# Finished  Minnesota  and  Alaska
# Finished  Minnesota  and  Arizona
# Finished  Minnesota  and  Arkansas
# Finished  Minnesota  and  California
# Finished  Minnesota  and  Colorado
# Finished  Minnesota  and  Connecticut
# Finished  Minnesota  and  Delaware
# Finished  Minnesota  and  D. of Columbia
# Finished  Minnesota  and  Florida
# Finished  Minnesota  and  Georgia
# Finished  Minnesota  and  Hawaii
# Finished  Minnesota  and  Idaho
# Finished  Minnesota  and  Illinois
# Finished  Minnesota  and  Indiana
# Finished  Minnesota  and  Iowa
# Finished  Minnesota  and  Kansas
# Finished  Minnesota  and  Kentucky
# Finished  Minnesota  and  Louisiana
# Finished  Minnesota  and  Maine
# Finished  Minnesota  and  Maryland
# Finished  Minnesota  and  Massachusetts
# Finished  Minnesota  and  Michigan
# Finished  Minnesota  and  Mississippi
# Finished  Minnesota  and  Missouri
# Finished  Minnesota  and  Montana
# Finished  Minnesota  and  Nebraska
# Finished  Minnesota  and  Nevada
# Finished  Minnesota  and  New Hampshire
# Finished  Minnesota  and  New Jersey
# Finished  Minnesota  and  New Mexico
# Finished  Minnesota  and  New York
# Finished  Minnesota  and  North Carolina
# ...
# Finished  NEW ENGLAND  and  Maryland
# Finished  NEW ENGLAND  and  Massachusetts
# Finished  NEW ENGLAND  and  Michigan
# Finished  NEW ENGLAND  and  Minnesota
# Finished  NEW ENGLAND  and  Mississippi
# Finished  NEW ENGLAND  and  Missouri
# Finished  NEW ENGLAND  and  Montana
# Finished  NEW ENGLAND  and  Nebraska
# Finished  NEW ENGLAND  and  Nevada
# Finished  NEW ENGLAND  and  New Hampshire
# Finished  NEW ENGLAND  and  New Jersey
# Finished  NEW ENGLAND  and  New Mexico
# Finished  NEW ENGLAND  and  New York
# Finished  NEW ENGLAND  and  North Carolina
# Finished  NEW ENGLAND  and  North Dakota
# Finished  NEW ENGLAND  and  Ohio
# Finished  NEW ENGLAND  and  Oklahoma
# Finished  NEW ENGLAND  and  Oregon
# Finished  NEW ENGLAND  and  Pennsylvania
# Finished  NEW ENGLAND  and  Rhode Island
# Finished  NEW ENGLAND  and  South Carolina
# Finished  NEW ENGLAND  and  South Dakota
# Finished  NEW ENGLAND  and  Tennessee
# Finished  NEW ENGLAND  and  Texas
# Finished  NEW ENGLAND  and  Utah
# Finished  NEW ENGLAND  and  Vermont
# Finished  NEW ENGLAND  and  Virginia
# Finished  NEW ENGLAND  and  Washington
# Finished  NEW ENGLAND  and  West Virginia
# Finished  NEW ENGLAND  and  Wisconsin
# Finished  NEW ENGLAND  and  Wyoming
# Finished  NEW ENGLAND  and  UNITED STATES
# Finished  NEW ENGLAND  and  MIDEAST
# Finished  NEW ENGLAND  and  GREAT LAKES
# Finished  NEW ENGLAND  and  PLAINS
# Finished  NEW ENGLAND  and  SOUTHEAST
# Finished  NEW ENGLAND  and  SOUTHWEST
# Finished  NEW ENGLAND  and  ROCKY MTN
# Finished  NEW ENGLAND  and  FAR WEST
# Finished  MIDEAST  and  Alabama
# Finished  MIDEAST  and  Alaska
# Finished  MIDEAST  and  Arizona
# Finished  MIDEAST  and  Arkansas
# Finished  MIDEAST  and  California
# Finished  MIDEAST  and  Colorado
# Finished  MIDEAST  and  Connecticut
# Finished  MIDEAST  and  Delaware
# Finished  MIDEAST  and  D. of Columbia
# Finished  MIDEAST  and  Florida
# Finished  MIDEAST  and  Georgia
# Finished  MIDEAST  and  Hawaii
# Finished  MIDEAST  and  Idaho
# Finished  MIDEAST  and  Illinois
# Finished  MIDEAST  and  Indiana
# Finished  MIDEAST  and  Iowa
# Finished  MIDEAST  and  Kansas
# Finished  MIDEAST  and  Kentucky
# Finished  MIDEAST  and  Louisiana
# Finished  MIDEAST  and  Maine
# Finished  MIDEAST  and  Maryland
# Finished  MIDEAST  and  Massachusetts
# Finished  MIDEAST  and  Michigan
# Finished  MIDEAST  and  Minnesota
# Finished  MIDEAST  and  Mississippi
# Finished  MIDEAST  and  Missouri
# Finished  MIDEAST  and  Montana
# Finished  MIDEAST  and  Nebraska
# Finished  MIDEAST  and  Nevada
# Finished  MIDEAST  and  New Hampshire
# Finished  MIDEAST  and  New Jersey
# Finished  MIDEAST  and  New Mexico
# Finished  MIDEAST  and  New York
# Finished  MIDEAST  and  North Carolina
# Finished  MIDEAST  and  North Dakota
# Finished  MIDEAST  and  Ohio
# Finished  MIDEAST  and  Oklahoma
# Finished  MIDEAST  and  Oregon
# Finished  MIDEAST  and  Pennsylvania
# Finished  MIDEAST  and  Rhode Island
# Finished  MIDEAST  and  South Carolina
# Finished  MIDEAST  and  South Dakota
# Finished  MIDEAST  and  Tennessee
# Finished  MIDEAST  and  Texas
# Finished  MIDEAST  and  Utah
# Finished  MIDEAST  and  Vermont
# Finished  MIDEAST  and  Virginia
# Finished  MIDEAST  and  Washington
# Finished  MIDEAST  and  West Virginia
# Finished  MIDEAST  and  Wisconsin
# Finished  MIDEAST  and  Wyoming
# Finished  MIDEAST  and  UNITED STATES
# Finished  MIDEAST  and  NEW ENGLAND
# Finished  MIDEAST  and  GREAT LAKES
# Finished  MIDEAST  and  PLAINS
# Finished  MIDEAST  and  SOUTHEAST
# Finished  MIDEAST  and  SOUTHWEST
# Finished  MIDEAST  and  ROCKY MTN
# Finished  MIDEAST  and  FAR WEST
# Finished  GREAT LAKES  and  Alabama
# Finished  GREAT LAKES  and  Alaska
# Finished  GREAT LAKES  and  Arizona
# Finished  GREAT LAKES  and  Arkansas
# Finished  GREAT LAKES  and  California
# Finished  GREAT LAKES  and  Colorado
# Finished  GREAT LAKES  and  Connecticut
# Finished  GREAT LAKES  and  Delaware
# Finished  GREAT LAKES  and  D. of Columbia
# Finished  GREAT LAKES  and  Florida
# Finished  GREAT LAKES  and  Georgia
# Finished  GREAT LAKES  and  Hawaii
# Finished  GREAT LAKES  and  Idaho
# Finished  GREAT LAKES  and  Illinois
# Finished  GREAT LAKES  and  Indiana
# Finished  GREAT LAKES  and  Iowa
# Finished  GREAT LAKES  and  Kansas
# Finished  GREAT LAKES  and  Kentucky
# Finished  GREAT LAKES  and  Louisiana
# Finished  GREAT LAKES  and  Maine
# Finished  GREAT LAKES  and  Maryland
# Finished  GREAT LAKES  and  Massachusetts
# Finished  GREAT LAKES  and  Michigan
# Finished  GREAT LAKES  and  Minnesota
# Finished  GREAT LAKES  and  Mississippi
# Finished  GREAT LAKES  and  Missouri
# Finished  GREAT LAKES  and  Montana
# Finished  GREAT LAKES  and  Nebraska
# Finished  GREAT LAKES  and  Nevada
# Finished  GREAT LAKES  and  New Hampshire
# Finished  GREAT LAKES  and  New Jersey
# Finished  GREAT LAKES  and  New Mexico
# Finished  GREAT LAKES  and  New York
# Finished  GREAT LAKES  and  North Carolina
# Finished  GREAT LAKES  and  North Dakota
# Finished  GREAT LAKES  and  Ohio
# Finished  GREAT LAKES  and  Oklahoma
# Finished  GREAT LAKES  and  Oregon
# Finished  GREAT LAKES  and  Pennsylvania
# Finished  GREAT LAKES  and  Rhode Island
# Finished  GREAT LAKES  and  South Carolina
# Finished  GREAT LAKES  and  South Dakota
# Finished  GREAT LAKES  and  Tennessee
# Finished  GREAT LAKES  and  Texas
# Finished  GREAT LAKES  and  Utah
# Finished  GREAT LAKES  and  Vermont
# Finished  GREAT LAKES  and  Virginia
# Finished  GREAT LAKES  and  Washington
# Finished  GREAT LAKES  and  West Virginia
# Finished  GREAT LAKES  and  Wisconsin
# Finished  GREAT LAKES  and  Wyoming
# Finished  GREAT LAKES  and  UNITED STATES
# Finished  GREAT LAKES  and  NEW ENGLAND
# Finished  GREAT LAKES  and  MIDEAST
# Finished  GREAT LAKES  and  PLAINS
# Finished  GREAT LAKES  and  SOUTHEAST
# Finished  GREAT LAKES  and  SOUTHWEST
# Finished  GREAT LAKES  and  ROCKY MTN
# Finished  GREAT LAKES  and  FAR WEST
# Finished  PLAINS  and  Alabama
# Finished  PLAINS  and  Alaska
# Finished  PLAINS  and  Arizona
# Finished  PLAINS  and  Arkansas
# Finished  PLAINS  and  California
# Finished  PLAINS  and  Colorado
# Finished  PLAINS  and  Connecticut
# Finished  PLAINS  and  Delaware
# Finished  PLAINS  and  D. of Columbia
# Finished  PLAINS  and  Florida
# Finished  PLAINS  and  Georgia
# Finished  PLAINS  and  Hawaii
# Finished  PLAINS  and  Idaho
# Finished  PLAINS  and  Illinois
# Finished  PLAINS  and  Indiana
# Finished  PLAINS  and  Iowa
# Finished  PLAINS  and  Kansas
# Finished  PLAINS  and  Kentucky
# Finished  PLAINS  and  Louisiana
# Finished  PLAINS  and  Maine
# Finished  PLAINS  and  Maryland
# Finished  PLAINS  and  Massachusetts
# Finished  PLAINS  and  Michigan
# Finished  PLAINS  and  Minnesota
# Finished  PLAINS  and  Mississippi
# Finished  PLAINS  and  Missouri
# Finished  PLAINS  and  Montana
# Finished  PLAINS  and  Nebraska
# Finished  PLAINS  and  Nevada
# Finished  PLAINS  and  New Hampshire
# Finished  PLAINS  and  New Jersey
# Finished  PLAINS  and  New Mexico
# Finished  PLAINS  and  New York
# Finished  PLAINS  and  North Carolina
# Finished  PLAINS  and  North Dakota
# Finished  PLAINS  and  Ohio
# Finished  PLAINS  and  Oklahoma
# Finished  PLAINS  and  Oregon
# Finished  PLAINS  and  Pennsylvania
# Finished  PLAINS  and  Rhode Island
# Finished  PLAINS  and  South Carolina
# Finished  PLAINS  and  South Dakota
# Finished  PLAINS  and  Tennessee
# Finished  PLAINS  and  Texas
# Finished  PLAINS  and  Utah
# Finished  PLAINS  and  Vermont
# Finished  PLAINS  and  Virginia
# Finished  PLAINS  and  Washington
# Finished  PLAINS  and  West Virginia
# Finished  PLAINS  and  Wisconsin
# Finished  PLAINS  and  Wyoming
# Finished  PLAINS  and  UNITED STATES
# Finished  PLAINS  and  NEW ENGLAND
# Finished  PLAINS  and  MIDEAST
# Finished  PLAINS  and  GREAT LAKES
# Finished  PLAINS  and  SOUTHEAST
# Finished  PLAINS  and  SOUTHWEST
# Finished  PLAINS  and  ROCKY MTN
# Finished  PLAINS  and  FAR WEST
# Finished  SOUTHEAST  and  Alabama
# Finished  SOUTHEAST  and  Alaska
# Finished  SOUTHEAST  and  Arizona
# Finished  SOUTHEAST  and  Arkansas
# Finished  SOUTHEAST  and  California
# Finished  SOUTHEAST  and  Colorado
# Finished  SOUTHEAST  and  Connecticut
# Finished  SOUTHEAST  and  Delaware
# Finished  SOUTHEAST  and  D. of Columbia
# Finished  SOUTHEAST  and  Florida
# Finished  SOUTHEAST  and  Georgia
# Finished  SOUTHEAST  and  Hawaii
# Finished  SOUTHEAST  and  Idaho
# Finished  SOUTHEAST  and  Illinois
# Finished  SOUTHEAST  and  Indiana
# Finished  SOUTHEAST  and  Iowa
# Finished  SOUTHEAST  and  Kansas
# Finished  SOUTHEAST  and  Kentucky
# Finished  SOUTHEAST  and  Louisiana
# Finished  SOUTHEAST  and  Maine
# Finished  SOUTHEAST  and  Maryland
# Finished  SOUTHEAST  and  Massachusetts
# Finished  SOUTHEAST  and  Michigan
# Finished  SOUTHEAST  and  Minnesota
# Finished  SOUTHEAST  and  Mississippi
# Finished  SOUTHEAST  and  Missouri
# Finished  SOUTHEAST  and  Montana
# Finished  SOUTHEAST  and  Nebraska
# Finished  SOUTHEAST  and  Nevada
# Finished  SOUTHEAST  and  New Hampshire
# Finished  SOUTHEAST  and  New Jersey
# Finished  SOUTHEAST  and  New Mexico
# Finished  SOUTHEAST  and  New York
# Finished  SOUTHEAST  and  North Carolina
# Finished  SOUTHEAST  and  North Dakota
# Finished  SOUTHEAST  and  Ohio
# Finished  SOUTHEAST  and  Oklahoma
# Finished  SOUTHEAST  and  Oregon
# Finished  SOUTHEAST  and  Pennsylvania
# Finished  SOUTHEAST  and  Rhode Island
# Finished  SOUTHEAST  and  South Carolina
# Finished  SOUTHEAST  and  South Dakota
# Finished  SOUTHEAST  and  Tennessee
# Finished  SOUTHEAST  and  Texas
# Finished  SOUTHEAST  and  Utah
# Finished  SOUTHEAST  and  Vermont
# Finished  SOUTHEAST  and  Virginia
# Finished  SOUTHEAST  and  Washington
# Finished  SOUTHEAST  and  West Virginia
# Finished  SOUTHEAST  and  Wisconsin
# Finished  SOUTHEAST  and  Wyoming
# Finished  SOUTHEAST  and  UNITED STATES
# Finished  SOUTHEAST  and  NEW ENGLAND
# Finished  SOUTHEAST  and  MIDEAST
# Finished  SOUTHEAST  and  GREAT LAKES
# Finished  SOUTHEAST  and  PLAINS
# Finished  SOUTHEAST  and  SOUTHWEST
# Finished  SOUTHEAST  and  ROCKY MTN
# Finished  SOUTHEAST  and  FAR WEST
# Finished  SOUTHWEST  and  Alabama
# Finished  SOUTHWEST  and  Alaska
# Finished  SOUTHWEST  and  Arizona
# Finished  SOUTHWEST  and  Arkansas
# Finished  SOUTHWEST  and  California
# Finished  SOUTHWEST  and  Colorado
# Finished  SOUTHWEST  and  Connecticut
# Finished  SOUTHWEST  and  Delaware
# Finished  SOUTHWEST  and  D. of Columbia
# Finished  SOUTHWEST  and  Florida
# Finished  SOUTHWEST  and  Georgia
# Finished  SOUTHWEST  and  Hawaii
# Finished  SOUTHWEST  and  Idaho
# Finished  SOUTHWEST  and  Illinois
# Finished  SOUTHWEST  and  Indiana
# Finished  SOUTHWEST  and  Iowa
# Finished  SOUTHWEST  and  Kansas
# Finished  SOUTHWEST  and  Kentucky
# Finished  SOUTHWEST  and  Louisiana
# Finished  SOUTHWEST  and  Maine
# Finished  SOUTHWEST  and  Maryland
# Finished  SOUTHWEST  and  Massachusetts
# Finished  SOUTHWEST  and  Michigan
# Finished  SOUTHWEST  and  Minnesota
# Finished  SOUTHWEST  and  Mississippi
# Finished  SOUTHWEST  and  Missouri
# Finished  SOUTHWEST  and  Montana
# Finished  SOUTHWEST  and  Nebraska
# Finished  SOUTHWEST  and  Nevada
# Finished  SOUTHWEST  and  New Hampshire
# Finished  SOUTHWEST  and  New Jersey
# Finished  SOUTHWEST  and  New Mexico
# Finished  SOUTHWEST  and  New York
# Finished  SOUTHWEST  and  North Carolina
# Finished  SOUTHWEST  and  North Dakota
# Finished  SOUTHWEST  and  Ohio
# Finished  SOUTHWEST  and  Oklahoma
# Finished  SOUTHWEST  and  Oregon
# Finished  SOUTHWEST  and  Pennsylvania
# Finished  SOUTHWEST  and  Rhode Island
# Finished  SOUTHWEST  and  South Carolina
# Finished  SOUTHWEST  and  South Dakota
# Finished  SOUTHWEST  and  Tennessee
# Finished  SOUTHWEST  and  Texas
# Finished  SOUTHWEST  and  Utah
# Finished  SOUTHWEST  and  Vermont
# Finished  SOUTHWEST  and  Virginia
# Finished  SOUTHWEST  and  Washington
# Finished  SOUTHWEST  and  West Virginia
# Finished  SOUTHWEST  and  Wisconsin
# Finished  SOUTHWEST  and  Wyoming
# Finished  SOUTHWEST  and  UNITED STATES
# Finished  SOUTHWEST  and  NEW ENGLAND
# Finished  SOUTHWEST  and  MIDEAST
# Finished  SOUTHWEST  and  GREAT LAKES
# Finished  SOUTHWEST  and  PLAINS
# Finished  SOUTHWEST  and  SOUTHEAST
# Finished  SOUTHWEST  and  ROCKY MTN
# Finished  SOUTHWEST  and  FAR WEST
# Finished  ROCKY MTN  and  Alabama
# Finished  ROCKY MTN  and  Alaska
# Finished  ROCKY MTN  and  Arizona
# Finished  ROCKY MTN  and  Arkansas
# Finished  ROCKY MTN  and  California
# Finished  ROCKY MTN  and  Colorado
# Finished  ROCKY MTN  and  Connecticut
# Finished  ROCKY MTN  and  Delaware
# Finished  ROCKY MTN  and  D. of Columbia
# Finished  ROCKY MTN  and  Florida
# Finished  ROCKY MTN  and  Georgia
# Finished  ROCKY MTN  and  Hawaii
# Finished  ROCKY MTN  and  Idaho
# Finished  ROCKY MTN  and  Illinois
# Finished  ROCKY MTN  and  Indiana
# Finished  ROCKY MTN  and  Iowa
# Finished  ROCKY MTN  and  Kansas
# Finished  ROCKY MTN  and  Kentucky
# Finished  ROCKY MTN  and  Louisiana
# Finished  ROCKY MTN  and  Maine
# Finished  ROCKY MTN  and  Maryland
# Finished  ROCKY MTN  and  Massachusetts
# Finished  ROCKY MTN  and  Michigan
# Finished  ROCKY MTN  and  Minnesota
# Finished  ROCKY MTN  and  Mississippi
# Finished  ROCKY MTN  and  Missouri
# Finished  ROCKY MTN  and  Montana
# Finished  ROCKY MTN  and  Nebraska
# Finished  ROCKY MTN  and  Nevada
# Finished  ROCKY MTN  and  New Hampshire
# Finished  ROCKY MTN  and  New Jersey
# Finished  ROCKY MTN  and  New Mexico
# Finished  ROCKY MTN  and  New York
# Finished  ROCKY MTN  and  North Carolina
# Finished  ROCKY MTN  and  North Dakota
# Finished  ROCKY MTN  and  Ohio
# Finished  ROCKY MTN  and  Oklahoma
# Finished  ROCKY MTN  and  Oregon
# Finished  ROCKY MTN  and  Pennsylvania
# Finished  ROCKY MTN  and  Rhode Island
# Finished  ROCKY MTN  and  South Carolina
# Finished  ROCKY MTN  and  South Dakota
# Finished  ROCKY MTN  and  Tennessee
# Finished  ROCKY MTN  and  Texas
# Finished  ROCKY MTN  and  Utah
# Finished  ROCKY MTN  and  Vermont
# Finished  ROCKY MTN  and  Virginia
# Finished  ROCKY MTN  and  Washington
# Finished  ROCKY MTN  and  West Virginia
# Finished  ROCKY MTN  and  Wisconsin
# Finished  ROCKY MTN  and  Wyoming
# Finished  ROCKY MTN  and  UNITED STATES
# Finished  ROCKY MTN  and  NEW ENGLAND
# Finished  ROCKY MTN  and  MIDEAST
# Finished  ROCKY MTN  and  GREAT LAKES
# Finished  ROCKY MTN  and  PLAINS
# Finished  ROCKY MTN  and  SOUTHEAST
# Finished  ROCKY MTN  and  SOUTHWEST
# Finished  ROCKY MTN  and  FAR WEST
# Finished  FAR WEST  and  Alabama
# Finished  FAR WEST  and  Alaska
# Finished  FAR WEST  and  Arizona
# Finished  FAR WEST  and  Arkansas
# Finished  FAR WEST  and  California
# Finished  FAR WEST  and  Colorado
# Finished  FAR WEST  and  Connecticut
# Finished  FAR WEST  and  Delaware
# Finished  FAR WEST  and  D. of Columbia
# Finished  FAR WEST  and  Florida
# Finished  FAR WEST  and  Georgia
# Finished  FAR WEST  and  Hawaii
# Finished  FAR WEST  and  Idaho
# Finished  FAR WEST  and  Illinois
# Finished  FAR WEST  and  Indiana
# Finished  FAR WEST  and  Iowa
# Finished  FAR WEST  and  Kansas
# Finished  FAR WEST  and  Kentucky
# Finished  FAR WEST  and  Louisiana
# Finished  FAR WEST  and  Maine
# Finished  FAR WEST  and  Maryland
# Finished  FAR WEST  and  Massachusetts
# Finished  FAR WEST  and  Michigan
# Finished  FAR WEST  and  Minnesota
# Finished  FAR WEST  and  Mississippi
# Finished  FAR WEST  and  Missouri
# Finished  FAR WEST  and  Montana
# Finished  FAR WEST  and  Nebraska
# Finished  FAR WEST  and  Nevada
# Finished  FAR WEST  and  New Hampshire
# Finished  FAR WEST  and  New Jersey
# Finished  FAR WEST  and  New Mexico
# Finished  FAR WEST  and  New York
# Finished  FAR WEST  and  North Carolina
# Finished  FAR WEST  and  North Dakota
# Finished  FAR WEST  and  Ohio
# Finished  FAR WEST  and  Oklahoma
# Finished  FAR WEST  and  Oregon
# Finished  FAR WEST  and  Pennsylvania
# Finished  FAR WEST  and  Rhode Island
# Finished  FAR WEST  and  South Carolina
# Finished  FAR WEST  and  South Dakota
# Finished  FAR WEST  and  Tennessee
# Finished  FAR WEST  and  Texas
# Finished  FAR WEST  and  Utah
# Finished  FAR WEST  and  Vermont
# Finished  FAR WEST  and  Virginia
# Finished  FAR WEST  and  Washington
# Finished  FAR WEST  and  West Virginia
# Finished  FAR WEST  and  Wisconsin
# Finished  FAR WEST  and  Wyoming
# Finished  FAR WEST  and  UNITED STATES
# Finished  FAR WEST  and  NEW ENGLAND
# Finished  FAR WEST  and  MIDEAST
# Finished  FAR WEST  and  GREAT LAKES
# Finished  FAR WEST  and  PLAINS
# Finished  FAR WEST  and  SOUTHEAST
# Finished  FAR WEST  and  SOUTHWEST
# Finished  FAR WEST  and  ROCKY MTN
# END!!!

# %%
# Economic correlation A&B 
from datetime import datetime
coincide = pd.read_excel('../data/coincident-index.xls')
#coincide = coincide[coincide['month']==12]
coincide.set_index('Date',inplace=True)
#coincide.drop(columns=['month','Date'],inplace=True)
coincide_df  = coincide.iloc[:,1:-3].stack()
coincide_df = coincide_df.reset_index()
coincide_df.columns=['index','level_1','coincident_index']
#coincide = coincide[coincide['level_1']!='US']
coincide_df['state'] = coincide_df['level_1'].apply(lambda x:state_full[x])
coincide_df.drop(columns=['level_1'],inplace=True)
coincide = coincide[coincide['year']<1998]

coincide_df['year'] = coincide_df['index'].dt.year
#coincide_df['month'] = coincide_df['Date'].dt.month
coincide = coincide_df[coincide_df['year']<1998]

def get_correlation(x):
    first_series = coincide[(coincide['state']==x['Acquiror State'])&(coincide['year']==x['announce_year'])]
    second_series = coincide[(coincide['state']==x['Target State'])&(coincide['year']==x['announce_year'])]
    t = pd.merge(first_series,second_series,on='index')
    return t[['coincident_index_x','coincident_index_y']].corr().values[0,1]

reg_df['Economic_correlation_AB'] = reg_df.apply(lambda row: get_correlation(row),axis=1)
reg_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\replication\Cornaggia and Li (2019)\workspace\variables_construct.ipynb Cell 13 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/replication/Cornaggia%20and%20Li%20%282019%29/workspace/variables_construct.ipynb#X54sZmlsZQ%3D%3D?line=10'>11</a> coincide_df['state'] = coincide_df['level_1'].apply(lambda x:state_full[x])
#      <a href='vscode-notebook-cell:/c%3A/replication/Cornaggia%20and%20Li%20%282019%29/workspace/variables_construct.ipynb#X54sZmlsZQ%3D%3D?line=11'>12</a> coincide_df.drop(columns=['level_1'],inplace=True)
# ---> <a href='vscode-notebook-cell:/c%3A/replication/Cornaggia%20and%20Li%20%282019%29/workspace/variables_construct.ipynb#X54sZmlsZQ%3D%3D?line=12'>13</a> coincide = coincide[coincide['year']<1998]
#      <a href='vscode-notebook-cell:/c%3A/replication/Cornaggia%20and%20Li%20%282019%29/workspace/variables_construct.ipynb#X54sZmlsZQ%3D%3D?line=14'>15</a> coincide_df['year'] = coincide_df['index'].dt.year
#      <a href='vscode-notebook-cell:/c%3A/replication/Cornaggia%20and%20Li%20%282019%29/workspace/variables_construct.ipynb#X54sZmlsZQ%3D%3D?line=15'>16</a> #coincide_df['month'] = coincide_df['Date'].dt.month
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'year'

# %%
## Tobins'q B-A
compustat = pd.read_csv('../data/compustats.csv')
compustat = compustat[compustat['loc']=='USA']
compustat = compustat[['fyear','cusip','conm','state','at','prcc_f','csho','ceq','txdb']]
compustat = compustat[compustat['at']>0.1]
compustat['tobinq'] = (compustat['prcc_f']*compustat['csho']+compustat['at']-compustat['ceq']-compustat['txdb'])/compustat['at']
tobinq_df = compustat.groupby(by = ['state','fyear'])['tobinq'].mean()
tobinq_df =tobinq_df.reset_index()
tobinq_df = tobinq_df[~tobinq_df['state'].isin(['PR','VI'])]
tobinq_df['state_full'] = tobinq_df['state'].apply(lambda x: state_full[x])

reg_df = pd.merge(reg_df,tobinq_df,left_on=['Acquiror State','announce_year'],right_on=['state_full','fyear'])
reg_df = pd.merge(reg_df,tobinq_df,left_on=['Target State','announce_year'],right_on=['state_full','fyear'],suffixes=('_acquire','_target'))
reg_df['tobinq_B-A'] = reg_df['tobinq_target']-reg_df['tobinq_acquire']
# Out:
# C:\Users\chuxu\AppData\Local\Temp\ipykernel_12928\1570192035.py:2: DtypeWarning: Columns (30,35,948,949,950,955,969,970,980) have mixed types. Specify dtype option on import or set low_memory=False.
#   compustat = pd.read_csv('../data/compustats.csv')

# %%
# stock return B-A
return_df = pd.read_csv('../data/stock_return.csv')
return_df = return_df[['CUSIP','CUSIP9','YYYYMM','MthRet']]
return_df['CUSIP9'] = return_df['CUSIP9'].astype(str)
compustat_state = compustat[['cusip','state']]
compustat_state['cusip'] = compustat_state['cusip'].astype(str)
compustat_state.drop_duplicates(inplace=True)
return_df = pd.merge(return_df,compustat_state,left_on='CUSIP9',right_on='cusip')

return_df['year'] = return_df['YYYYMM']//100
return_df['payoff'] = return_df['MthRet']+1
return_df.sort_values(by = ['CUSIP9','YYYYMM'],ascending=[True,True],inplace=True)

ret_df = return_df.groupby(by = ['CUSIP9','year'])['payoff'].prod()-1
ret_df = ret_df.reset_index()
ret_df = pd.merge(ret_df,compustat_state,left_on='CUSIP9',right_on='cusip')
ret_df = ret_df.groupby(by=['state','year'])['payoff'].mean()
ret_df = ret_df.reset_index()
ret_df = ret_df[~ret_df['state'].isin(['PR','VI'])]
ret_df['state_full'] = ret_df['state'].apply(lambda x: state_full[x])

reg_df = pd.merge(reg_df,ret_df,how = 'left',left_on=['Acquiror State','announce_year'],right_on=['state_full','year'])
reg_df = pd.merge(reg_df,ret_df,how = 'left',left_on=['Target State','announce_year'],right_on=['state_full','year'],suffixes=('_acquire','_target'))
reg_df['stock_return_B-A'] = reg_df['payoff_target'] - reg_df['payoff_acquire']

reg_df.drop(columns=['year_x','year_y', 'State.1_acquire','State.1_target','fyear_target','fyear_acquire','year','state_full_target','state_full_acquire','state_target','state_acquire'],inplace=True)
# Out:
# C:\Users\chuxu\AppData\Local\Temp\ipykernel_12928\2567774867.py:2: DtypeWarning: Columns (6,7,8,9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   return_df = pd.read_csv('../data/stock_return.csv')
# C:\Users\chuxu\AppData\Local\Temp\ipykernel_12928\2567774867.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compustat_state['cusip'] = compustat_state['cusip'].astype(str)
# C:\Users\chuxu\AppData\Local\Temp\ipykernel_12928\2567774867.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compustat_state.drop_duplicates(inplace=True)
# C:\Users\chuxu\AppData\Local\Temp\ipykernel_12928\2567774867.py:23: FutureWarning: Passing 'suffixes' which cause duplicate columns {'state_full_acquire', 'state_acquire'} in the result is deprecated and will raise a MergeError in a future version.
#   reg_df = pd.merge(reg_df,ret_df,how = 'left',left_on=['Target State','announce_year'],right_on=['state_full','year'],suffixes=('_acquire','_target'))

# %%
## unemployment B-A
unemployment = pd.read_excel('../data/emp-unemployment.xls',header=5,sheet_name='States')
unemployment = unemployment.iloc[:-9,:]
unemployment.drop(columns=['Fips'],inplace=True)
unemployment.set_index('Area',inplace=True)
unemployment = unemployment.stack()
unemployment = unemployment.reset_index()
unemployment.loc[unemployment['Area']=='District of Columbia','Area']='D. of Columbia'
unemployment = unemployment[unemployment['Area']!='United States']
unemployment.columns = ['Area','year','unemployment']

reg_df = pd.merge(reg_df,unemployment,left_on=['Acquiror State','announce_year'],right_on=['Area','year'])
reg_df = pd.merge(reg_df,unemployment,left_on=['Target State','announce_year'],right_on=['Area','year'],suffixes=('_acquire','_target'))
reg_df['unemployment_B-A'] = reg_df['unemployment_target']- reg_df['unemployment_acquire']

# %%
## Anti-combination B-A
def get_anti(x,target = 'target'):
    if str(x['Year BC Passed_%s'%target])=='nan':
        return 0
    else:
        if x['Year BC Passed_%s'%target]> x['announce_year']:
            return 0
        else:
            return 1
anti = pd.read_excel('../data/policy.xlsx')
anti = anti[['State','Year BC Passed']]
anti.dropna(how='all',inplace=True)

reg_df = pd.merge(reg_df,anti,how='left',left_on=['Acquiror State'],right_on='State')
reg_df = pd.merge(reg_df,anti,how='left',left_on=['Target State'],right_on='State',suffixes=('_acquire','_target'))

reg_df['anti_competition_acquire'] = reg_df.apply(lambda x: get_anti(x,'acquire'),axis=1)
reg_df['anti_competition_target'] = reg_df.apply(lambda x: get_anti(x,'target'),axis=1)
reg_df['anti_competition_B-A'] = reg_df['anti_competition_target'] - reg_df['anti_competition_acquire']
reg_df.drop(columns=['State_acquire','State_target'],inplace=True)

# %%
## corporate tax rate B-A
tax_df = pd.read_excel('../data/State Corporate Income Tax Rates, 2000-2014.xlsx',sheet_name='arrange')
reg_df = pd.merge(reg_df,tax_df,left_on='Acquiror State',right_on='State')
reg_df = pd.merge(reg_df,tax_df,left_on='Target State',right_on='State',suffixes=('_acquire','_target'))
reg_df['Corporate_income_tax_B-A'] = reg_df['rate_target'] - reg_df['rate_acquire']
reg_df.to_excel('baseline.xlsx')
